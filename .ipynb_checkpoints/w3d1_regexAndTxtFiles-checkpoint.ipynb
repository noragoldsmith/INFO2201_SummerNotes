# %% [markdown]
# # Week 3 Day 1: Files, .txt files and Regular Expressions
# *   Reading and downloading files
# *   Introduction to regular expressions

# %% [markdown]
# ## Files
#
# Where files are downloaded to are not the same as where you are working necesarily
#
# **Lets take a moment to download the .txt file on the week 2 module, see where it is compared to where we are working**
#
# *Laurie -- do this and screenshare*

# %% [markdown]
# ### OS Package
# this is a package that can help you navigate different files and folders within your operating control.

# %%
### Import OS

import os

# %%
#get your current working directory

path = os.getcwd()

print(path)
# Out:
# /Users/noragoldsmith/Documents/GitHub/INFO2201_SummerNotes

# %% [markdown]
# ### File Handling
# The key function for working with files in Python is the open() function.
#
# The **open()** function takes two parameters; filename, and mode.
#
# There are four different methods (modes) for opening a file:
# - "r" - Read - Default value. Opens a file for reading, error if the file does not exist
# - "a" - Append - Opens a file for appending, creates the file if it does not exist
# - "w" - Write - Opens a file for writing, creates the file if it does not exist
# - "x" - Create - Creates the specified file, returns an error if the file exists
#
# In addition you can specify if the file should be handled as binary or text mode
# - "t" - Text - Default value. Text mode
# - "b" - Binary - Binary mode (e.g. images)

# %%
f = open("demofile.txt")
f.close()

# %% [markdown]
# is the same as

# %%
f = open("demofile.txt", "rt")
f.close()

# %% [markdown]
# Because "r" for read, and "t" for text are the default values, you do not need to specify them.
#
# However we will not use open() alone we will use..

# %%
#example 1
with open("demofile.txt", "r") as f:
    lines = f.readlines()

#example 2
with open("demofile.txt", "r") as f:
    fullFile = f.read()

# %% [markdown]
#  #### we use with because it automatically closes the file when we're done with it
#
# Once you get your file imported into the code there are many other methods that you can work with
# - read()
# - readlines()
# - strip()

# %%
#import the .txt file
# programmingImportance.txt

with open("data/programmingImportance.txt", "r") as f:
    lines = f.readlines()

lines
# Out:
# ['Introduction:\n',
#  "In today's increasingly digital world, learning programming has become more important than ever before. Programming is not only a valuable skill for computer scientists and software engineers but also holds relevance for individuals across various disciplines. From driving innovation to enhancing problem-solving abilities, the benefits of learning programming are numerous and far-reaching. This article aims to shed light on why learning programming is crucial in the modern era.\n",
#  '\n',
#  'Driving Technological Innovation:\n',
#  'Programming is the backbone of technological innovation. It empowers individuals to create software, applications, and tools that shape our daily lives. By learning programming, individuals can actively contribute to the development of new technologies and drive innovation forward. From designing mobile apps that simplify everyday tasks to building complex algorithms for artificial intelligence, programming skills play a pivotal role in shaping the future of technology.\n',
#  '\n',
#  'Enhancing Problem-Solving Skills:\n',
#  'Programming is essentially about problem-solving. It requires breaking down complex problems into smaller, manageable tasks and developing logical solutions. By learning programming, individuals cultivate analytical thinking, logical reasoning, and the ability to approach challenges systematically. These problem-solving skills are transferable and valuable in various areas of life, such as academia, business, and personal decision-making.\n',
#  '\n',
#  'Fostering Creativity:\n',
#  'Programming offers a creative outlet that enables individuals to bring their ideas to life. It provides a platform for innovation and experimentation, where individuals can express their unique perspectives and create something meaningful. The process of programming encourages individuals to think outside the box, find creative solutions, and explore new possibilities. By nurturing creativity, programming empowers individuals to tackle problems in unconventional ways and contribute to diverse fields beyond computer science.\n',
#  '\n',
#  'Expanding Career Opportunities:\n',
#  "In today's job market, programming skills are highly sought after. Proficiency in programming opens up a wide range of career opportunities across industries. From software development to data analysis, web design to cybersecurity, programming skills are in demand across diverse sectors. Learning programming equips individuals with a versatile skill set that increases their employability and enables them to adapt to rapidly evolving job markets.\n",
#  '\n',
#  'Understanding the Digital World:\n',
#  'In an era dominated by technology, understanding the digital world is essential. Learning programming provides individuals with insights into the underlying mechanics of software and applications that are pervasive in our lives. It allows individuals to grasp concepts such as algorithms, data structures, and computational thinking. This knowledge not only enables individuals to navigate digital platforms more effectively but also helps them make informed decisions regarding privacy, security, and digital literacy.\n',
#  '\n',
#  'Empowering Entrepreneurship:\n',
#  'Programming skills can be a catalyst for entrepreneurship. With the rise of digital startups and online businesses, the ability to create software solutions has become a crucial advantage. By learning programming, individuals can transform their ideas into functional prototypes, build minimum viable products (MVPs), and develop scalable platforms. Programming knowledge empowers aspiring entrepreneurs to turn their visions into reality, disrupt industries, and create innovative solutions to address real-world problems.\n',
#  '\n',
#  'Conclusion:\n',
#  "Learning programming is an investment in the future. It equips individuals with invaluable skills that extend beyond the realm of computer science. From driving technological innovation to enhancing problem-solving abilities, programming is a powerful tool that opens doors to new opportunities. By acquiring programming skills, individuals become active participants in shaping the digital world and making a positive impact on society. Whether it's pursuing a career in technology or applying programming principles to other domains, the importance of learning programming in today's world cannot be overstated."]

# %%
#print a line as the line is read

with open("data/programmingImportance.txt", "r") as f:
    lines = f.readlines()

    for line in lines:
        print(line)
# Out:
# Introduction:
#
# In today's increasingly digital world, learning programming has become more important than ever before. Programming is not only a valuable skill for computer scientists and software engineers but also holds relevance for individuals across various disciplines. From driving innovation to enhancing problem-solving abilities, the benefits of learning programming are numerous and far-reaching. This article aims to shed light on why learning programming is crucial in the modern era.
#
#
#
# Driving Technological Innovation:
#
# Programming is the backbone of technological innovation. It empowers individuals to create software, applications, and tools that shape our daily lives. By learning programming, individuals can actively contribute to the development of new technologies and drive innovation forward. From designing mobile apps that simplify everyday tasks to building complex algorithms for artificial intelligence, programming skills play a pivotal role in shaping the future of technology.
#
#
#
# Enhancing Problem-Solving Skills:
#
# Programming is essentially about problem-solving. It requires breaking down complex problems into smaller, manageable tasks and developing logical solutions. By learning programming, individuals cultivate analytical thinking, logical reasoning, and the ability to approach challenges systematically. These problem-solving skills are transferable and valuable in various areas of life, such as academia, business, and personal decision-making.
#
#
#
# Fostering Creativity:
#
# Programming offers a creative outlet that enables individuals to bring their ideas to life. It provides a platform for innovation and experimentation, where individuals can express their unique perspectives and create something meaningful. The process of programming encourages individuals to think outside the box, find creative solutions, and explore new possibilities. By nurturing creativity, programming empowers individuals to tackle problems in unconventional ways and contribute to diverse fields beyond computer science.
#
#
#
# Expanding Career Opportunities:
#
# In today's job market, programming skills are highly sought after. Proficiency in programming opens up a wide range of career opportunities across industries. From software development to data analysis, web design to cybersecurity, programming skills are in demand across diverse sectors. Learning programming equips individuals with a versatile skill set that increases their employability and enables them to adapt to rapidly evolving job markets.
#
#
#
# Understanding the Digital World:
#
# In an era dominated by technology, understanding the digital world is essential. Learning programming provides individuals with insights into the underlying mechanics of software and applications that are pervasive in our lives. It allows individuals to grasp concepts such as algorithms, data structures, and computational thinking. This knowledge not only enables individuals to navigate digital platforms more effectively but also helps them make informed decisions regarding privacy, security, and digital literacy.
#
#
#
# Empowering Entrepreneurship:
#
# Programming skills can be a catalyst for entrepreneurship. With the rise of digital startups and online businesses, the ability to create software solutions has become a crucial advantage. By learning programming, individuals can transform their ideas into functional prototypes, build minimum viable products (MVPs), and develop scalable platforms. Programming knowledge empowers aspiring entrepreneurs to turn their visions into reality, disrupt industries, and create innovative solutions to address real-world problems.
#
#
#
# Conclusion:
#
# Learning programming is an investment in the future. It equips individuals with invaluable skills that extend beyond the realm of computer science. From driving technological innovation to enhancing problem-solving abilities, programming is a powerful tool that opens doors to new opportunities. By acquiring programming skills, individuals become active participants in shaping the digital world and making a positive impact on society. Whether it's pursuing a career in technology or applying programming principles to other domains, the importance of learning programming in today's world cannot be overstated.

# %% [markdown]
# **.strip()**
# this removes any leading, and trailing whitespaces

# %%
#example make one with alot of white spaces

txt = "       banana        "

cleanText = txt.strip()

cleanText
# Out:
# 'banana'

# %%
# strip the line as it is read for our file

with open("data/programmingImportance.txt", "r") as f:
    lines = f.readlines()

    for line in lines:
        cleanLine = line.strip()
        print(cleanLine)
# Out:
# Introduction:
# In today's increasingly digital world, learning programming has become more important than ever before. Programming is not only a valuable skill for computer scientists and software engineers but also holds relevance for individuals across various disciplines. From driving innovation to enhancing problem-solving abilities, the benefits of learning programming are numerous and far-reaching. This article aims to shed light on why learning programming is crucial in the modern era.
#
# Driving Technological Innovation:
# Programming is the backbone of technological innovation. It empowers individuals to create software, applications, and tools that shape our daily lives. By learning programming, individuals can actively contribute to the development of new technologies and drive innovation forward. From designing mobile apps that simplify everyday tasks to building complex algorithms for artificial intelligence, programming skills play a pivotal role in shaping the future of technology.
#
# Enhancing Problem-Solving Skills:
# Programming is essentially about problem-solving. It requires breaking down complex problems into smaller, manageable tasks and developing logical solutions. By learning programming, individuals cultivate analytical thinking, logical reasoning, and the ability to approach challenges systematically. These problem-solving skills are transferable and valuable in various areas of life, such as academia, business, and personal decision-making.
#
# Fostering Creativity:
# Programming offers a creative outlet that enables individuals to bring their ideas to life. It provides a platform for innovation and experimentation, where individuals can express their unique perspectives and create something meaningful. The process of programming encourages individuals to think outside the box, find creative solutions, and explore new possibilities. By nurturing creativity, programming empowers individuals to tackle problems in unconventional ways and contribute to diverse fields beyond computer science.
#
# Expanding Career Opportunities:
# In today's job market, programming skills are highly sought after. Proficiency in programming opens up a wide range of career opportunities across industries. From software development to data analysis, web design to cybersecurity, programming skills are in demand across diverse sectors. Learning programming equips individuals with a versatile skill set that increases their employability and enables them to adapt to rapidly evolving job markets.
#
# Understanding the Digital World:
# In an era dominated by technology, understanding the digital world is essential. Learning programming provides individuals with insights into the underlying mechanics of software and applications that are pervasive in our lives. It allows individuals to grasp concepts such as algorithms, data structures, and computational thinking. This knowledge not only enables individuals to navigate digital platforms more effectively but also helps them make informed decisions regarding privacy, security, and digital literacy.
#
# Empowering Entrepreneurship:
# Programming skills can be a catalyst for entrepreneurship. With the rise of digital startups and online businesses, the ability to create software solutions has become a crucial advantage. By learning programming, individuals can transform their ideas into functional prototypes, build minimum viable products (MVPs), and develop scalable platforms. Programming knowledge empowers aspiring entrepreneurs to turn their visions into reality, disrupt industries, and create innovative solutions to address real-world problems.
#
# Conclusion:
# Learning programming is an investment in the future. It equips individuals with invaluable skills that extend beyond the realm of computer science. From driving technological innovation to enhancing problem-solving abilities, programming is a powerful tool that opens doors to new opportunities. By acquiring programming skills, individuals become active participants in shaping the digital world and making a positive impact on society. Whether it's pursuing a career in technology or applying programming principles to other domains, the importance of learning programming in today's world cannot be overstated.

# %%
# strip each line with a for loop

with open("data/programmingImportance.txt", "r", encoding = "utf8") as f:
    lines = f.readlines()

    for line in lines:
        cleanLine = line.strip()
        print(cleanLine)
# Out:
# Introduction:
# In today's increasingly digital world, learning programming has become more important than ever before. Programming is not only a valuable skill for computer scientists and software engineers but also holds relevance for individuals across various disciplines. From driving innovation to enhancing problem-solving abilities, the benefits of learning programming are numerous and far-reaching. This article aims to shed light on why learning programming is crucial in the modern era.
#
# Driving Technological Innovation:
# Programming is the backbone of technological innovation. It empowers individuals to create software, applications, and tools that shape our daily lives. By learning programming, individuals can actively contribute to the development of new technologies and drive innovation forward. From designing mobile apps that simplify everyday tasks to building complex algorithms for artificial intelligence, programming skills play a pivotal role in shaping the future of technology.
#
# Enhancing Problem-Solving Skills:
# Programming is essentially about problem-solving. It requires breaking down complex problems into smaller, manageable tasks and developing logical solutions. By learning programming, individuals cultivate analytical thinking, logical reasoning, and the ability to approach challenges systematically. These problem-solving skills are transferable and valuable in various areas of life, such as academia, business, and personal decision-making.
#
# Fostering Creativity:
# Programming offers a creative outlet that enables individuals to bring their ideas to life. It provides a platform for innovation and experimentation, where individuals can express their unique perspectives and create something meaningful. The process of programming encourages individuals to think outside the box, find creative solutions, and explore new possibilities. By nurturing creativity, programming empowers individuals to tackle problems in unconventional ways and contribute to diverse fields beyond computer science.
#
# Expanding Career Opportunities:
# In today's job market, programming skills are highly sought after. Proficiency in programming opens up a wide range of career opportunities across industries. From software development to data analysis, web design to cybersecurity, programming skills are in demand across diverse sectors. Learning programming equips individuals with a versatile skill set that increases their employability and enables them to adapt to rapidly evolving job markets.
#
# Understanding the Digital World:
# In an era dominated by technology, understanding the digital world is essential. Learning programming provides individuals with insights into the underlying mechanics of software and applications that are pervasive in our lives. It allows individuals to grasp concepts such as algorithms, data structures, and computational thinking. This knowledge not only enables individuals to navigate digital platforms more effectively but also helps them make informed decisions regarding privacy, security, and digital literacy.
#
# Empowering Entrepreneurship:
# Programming skills can be a catalyst for entrepreneurship. With the rise of digital startups and online businesses, the ability to create software solutions has become a crucial advantage. By learning programming, individuals can transform their ideas into functional prototypes, build minimum viable products (MVPs), and develop scalable platforms. Programming knowledge empowers aspiring entrepreneurs to turn their visions into reality, disrupt industries, and create innovative solutions to address real-world problems.
#
# Conclusion:
# Learning programming is an investment in the future. It equips individuals with invaluable skills that extend beyond the realm of computer science. From driving technological innovation to enhancing problem-solving abilities, programming is a powerful tool that opens doors to new opportunities. By acquiring programming skills, individuals become active participants in shaping the digital world and making a positive impact on society. Whether it's pursuing a career in technology or applying programming principles to other domains, the importance of learning programming in today's world cannot be overstated.

# %%
#assign the content in the file to a variable

with open("data/programmingImportance.txt", "r", encoding = "utf8") as file:
    myString = file.read()

myString
# Out:
# "Introduction:\nIn today's increasingly digital world, learning programming has become more important than ever before. Programming is not only a valuable skill for computer scientists and software engineers but also holds relevance for individuals across various disciplines. From driving innovation to enhancing problem-solving abilities, the benefits of learning programming are numerous and far-reaching. This article aims to shed light on why learning programming is crucial in the modern era.\n\nDriving Technological Innovation:\nProgramming is the backbone of technological innovation. It empowers individuals to create software, applications, and tools that shape our daily lives. By learning programming, individuals can actively contribute to the development of new technologies and drive innovation forward. From designing mobile apps that simplify everyday tasks to building complex algorithms for artificial intelligence, programming skills play a pivotal role in shaping the future of technology.\n\nEnhancing Problem-Solving Skills:\nProgramming is essentially about problem-solving. It requires breaking down complex problems into smaller, manageable tasks and developing logical solutions. By learning programming, individuals cultivate analytical thinking, logical reasoning, and the ability to approach challenges systematically. These problem-solving skills are transferable and valuable in various areas of life, such as academia, business, and personal decision-making.\n\nFostering Creativity:\nProgramming offers a creative outlet that enables individuals to bring their ideas to life. It provides a platform for innovation and experimentation, where individuals can express their unique perspectives and create something meaningful. The process of programming encourages individuals to think outside the box, find creative solutions, and explore new possibilities. By nurturing creativity, programming empowers individuals to tackle problems in unconventional ways and contribute to diverse fields beyond computer science.\n\nExpanding Career Opportunities:\nIn today's job market, programming skills are highly sought after. Proficiency in programming opens up a wide range of career opportunities across industries. From software development to data analysis, web design to cybersecurity, programming skills are in demand across diverse sectors. Learning programming equips individuals with a versatile skill set that increases their employability and enables them to adapt to rapidly evolving job markets.\n\nUnderstanding the Digital World:\nIn an era dominated by technology, understanding the digital world is essential. Learning programming provides individuals with insights into the underlying mechanics of software and applications that are pervasive in our lives. It allows individuals to grasp concepts such as algorithms, data structures, and computational thinking. This knowledge not only enables individuals to navigate digital platforms more effectively but also helps them make informed decisions regarding privacy, security, and digital literacy.\n\nEmpowering Entrepreneurship:\nProgramming skills can be a catalyst for entrepreneurship. With the rise of digital startups and online businesses, the ability to create software solutions has become a crucial advantage. By learning programming, individuals can transform their ideas into functional prototypes, build minimum viable products (MVPs), and develop scalable platforms. Programming knowledge empowers aspiring entrepreneurs to turn their visions into reality, disrupt industries, and create innovative solutions to address real-world problems.\n\nConclusion:\nLearning programming is an investment in the future. It equips individuals with invaluable skills that extend beyond the realm of computer science. From driving technological innovation to enhancing problem-solving abilities, programming is a powerful tool that opens doors to new opportunities. By acquiring programming skills, indivi ...

# %% [markdown]
# ### Exercise 1:
# import yoga.txt and find out which word is said the most

# %%
with open("data/yoga.txt", "r", encoding = "utf8") as file:
    yoga = file.read()

yoga
# Out:
# "The ancient yogic discipline is far more than a fitness method for physical health or a psychological tool to achieve peace and happiness. \n    Wellness of body and mind, often touted as the primary benefit of modern yoga practice, is merely a by-product of becoming a fully balanced and vibrantly alive being. \n    The Sanskrit word 'yoga' comes from the word 'yuj' which means, 'to unite'.\n    Hence, yoga is the union of the individual with the whole of existence, also commonly referred to as 'self-realization', 'nirvana', 'mukti',  or 'enlightenment'.\n    Yoga also refers to the inner technology that will lead one to this experience – a technology formulated from rigorous inner observation, by ancient yogis over thousands of years.\n    With their extraordinary perception and mastery over every aspect of the human mechanism, these great yogis delved into their own systems, uncovering the nature of the cosmos – a macrocosm of the human system.\n    Initially, yoga was imparted by the Adiyogi (the first yogi), Shiva, over 15,000 years ago. \n    It was Adiyogi who introduced to humanity the idea that one can evolve beyond one’s present level of existence. \n    He poured his knowing into the legendary Sapta Rishis, or seven sages, who took the tremendous possibility offered by the yogic science to various parts of the world, including Asia, ancient Persia, northern Africa, and South America. \n    It is this fundamental yet sophisticated science of elevating human consciousness that is the source of the world’s spiritual traditions, predating religion by many thousands of years."

# %%
yoga.split(" ")
# Out:
# ['The',
#  'ancient',
#  'yogic',
#  'discipline',
#  'is',
#  'far',
#  'more',
#  'than',
#  'a',
#  'fitness',
#  'method',
#  'for',
#  'physical',
#  'health',
#  'or',
#  'a',
#  'psychological',
#  'tool',
#  'to',
#  'achieve',
#  'peace',
#  'and',
#  'happiness.',
#  '\n',
#  '',
#  '',
#  '',
#  'Wellness',
#  'of',
#  'body',
#  'and',
#  'mind,',
#  'often',
#  'touted',
#  'as',
#  'the',
#  'primary',
#  'benefit',
#  'of',
#  'modern',
#  'yoga',
#  'practice,',
#  'is',
#  'merely',
#  'a',
#  'by-product',
#  'of',
#  'becoming',
#  'a',
#  'fully',
#  'balanced',
#  'and',
#  'vibrantly',
#  'alive',
#  'being.',
#  '\n',
#  '',
#  '',
#  '',
#  'The',
#  'Sanskrit',
#  'word',
#  "'yoga'",
#  'comes',
#  'from',
#  'the',
#  'word',
#  "'yuj'",
#  'which',
#  'means,',
#  "'to",
#  "unite'.\n",
#  '',
#  '',
#  '',
#  'Hence,',
#  'yoga',
#  'is',
#  'the',
#  'union',
#  'of',
#  'the',
#  'individual',
#  'with',
#  'the',
#  'whole',
#  'of',
#  'existence,',
#  'also',
#  'commonly',
#  'referred',
#  'to',
#  'as',
#  "'self-realization',",
#  "'nirvana',",
#  "'mukti',",
#  '',
#  'or',
#  "'enlightenment'.\n",
#  '',
#  '',
#  '',
#  'Yoga',
#  'also',
#  'refers',
#  'to',
#  'the',
#  'inner',
#  'technology',
#  'that',
#  'will',
#  'lead',
#  'one',
#  'to',
#  'this',
#  'experience',
#  '–',
#  'a',
#  'technology',
#  'formulated',
#  'from',
#  'rigorous',
#  'inner',
#  'observation,',
#  'by',
#  'ancient',
#  'yogis',
#  'over',
#  'thousands',
#  'of',
#  'years.\n',
#  '',
#  '',
#  '',
#  'With',
#  'their',
#  'extraordinary',
#  'perception',
#  'and',
#  'mastery',
#  'over',
#  'every',
#  'aspect',
#  'of',
#  'the',
#  'human',
#  'mechanism,',
#  'these',
#  'great',
#  'yogis',
#  'delved',
#  'into',
#  'their',
#  'own',
#  'systems,',
#  'uncovering',
#  'the',
#  'nature',
#  'of',
#  'the',
#  'cosmos',
#  '–',
#  'a',
#  'macrocosm',
#  'of',
#  'the',
#  'human',
#  'system.\n',
#  '',
#  '',
#  '',
#  'Initially,',
#  'yoga',
#  'was',
#  'imparted',
#  'by',
#  'the',
#  'Adiyogi',
#  '(the',
#  'first',
#  'yogi),',
#  'Shiva,',
#  'over',
#  '15,000',
#  'years',
#  'ago.',
#  '\n',
#  '',
#  '',
#  '',
#  'It',
#  'was',
#  'Adiyogi',
#  'who',
#  'introduced',
#  'to',
#  'humanity',
#  'the',
#  'idea',
#  'that',
#  'one',
#  'can',
#  'evolve',
#  'beyond',
#  'one’s',
#  'present',
#  'level',
#  'of',
#  'existence.',
#  '\n',
#  '',
#  '',
#  '',
#  'He',
#  'poured',
#  'his',
#  'knowing',
#  'into',
#  'the',
#  'legendary',
#  'Sapta',
#  'Rishis,',
#  'or',
#  'seven',
#  'sages,',
#  'who',
#  'took',
#  'the',
#  'tremendous',
#  'possibility',
#  'offered',
#  'by',
#  'the',
#  'yogic',
#  'science',
#  'to',
#  'various',
#  'parts',
#  'of',
#  'the',
#  'world,',
#  'including',
#  'Asia,',
#  'ancient',
#  'Persia,',
#  'northern',
#  'Africa,',
#  'and',
#  'South',
#  'America.',
#  '\n',
#  '',
#  '',
#  '',
#  'It',
#  'is',
#  'this',
#  'fundamental',
#  'yet',
#  'sophisticated',
#  'science',
#  'of',
#  'elevating',
#  'human',
#  'consciousness',
#  'that',
#  'is',
#  'the',
#  'source',
#  'of',
#  'the',
#  'world’s',
#  'spiritual',
#  'traditions,',
#  'predating',
#  'religion',
#  'by',
#  'many',
#  'thousands',
#  'of',
#  'years.']

# %%
wordQuant = {}

for word in yoga.split(" "):
    if word in wordQuant.keys():
        wordQuant[word] += 1

    else:
        wordQuant[word] = 1

# %%
wordQuant
# Out:
# {'The': 2,
#  'ancient': 3,
#  'yogic': 2,
#  'discipline': 1,
#  'is': 5,
#  'far': 1,
#  'more': 1,
#  'than': 1,
#  'a': 6,
#  'fitness': 1,
#  'method': 1,
#  'for': 1,
#  'physical': 1,
#  'health': 1,
#  'or': 3,
#  'psychological': 1,
#  'tool': 1,
#  'to': 6,
#  'achieve': 1,
#  'peace': 1,
#  'and': 5,
#  'happiness.': 1,
#  '\n': 5,
#  '': 28,
#  'Wellness': 1,
#  'of': 14,
#  'body': 1,
#  'mind,': 1,
#  'often': 1,
#  'touted': 1,
#  'as': 2,
#  'the': 18,
#  'primary': 1,
#  'benefit': 1,
#  'modern': 1,
#  'yoga': 3,
#  'practice,': 1,
#  'merely': 1,
#  'by-product': 1,
#  'becoming': 1,
#  'fully': 1,
#  'balanced': 1,
#  'vibrantly': 1,
#  'alive': 1,
#  'being.': 1,
#  'Sanskrit': 1,
#  'word': 2,
#  "'yoga'": 1,
#  'comes': 1,
#  'from': 2,
#  "'yuj'": 1,
#  'which': 1,
#  'means,': 1,
#  "'to": 1,
#  "unite'.\n": 1,
#  'Hence,': 1,
#  'union': 1,
#  'individual': 1,
#  'with': 1,
#  'whole': 1,
#  'existence,': 1,
#  'also': 2,
#  'commonly': 1,
#  'referred': 1,
#  "'self-realization',": 1,
#  "'nirvana',": 1,
#  "'mukti',": 1,
#  "'enlightenment'.\n": 1,
#  'Yoga': 1,
#  'refers': 1,
#  'inner': 2,
#  'technology': 2,
#  'that': 3,
#  'will': 1,
#  'lead': 1,
#  'one': 2,
#  'this': 2,
#  'experience': 1,
#  '–': 2,
#  'formulated': 1,
#  'rigorous': 1,
#  'observation,': 1,
#  'by': 4,
#  'yogis': 2,
#  'over': 3,
#  'thousands': 2,
#  'years.\n': 1,
#  'With': 1,
#  'their': 2,
#  'extraordinary': 1,
#  'perception': 1,
#  'mastery': 1,
#  'every': 1,
#  'aspect': 1,
#  'human': 3,
#  'mechanism,': 1,
#  'these': 1,
#  'great': 1,
#  'delved': 1,
#  'into': 2,
#  'own': 1,
#  'systems,': 1,
#  'uncovering': 1,
#  'nature': 1,
#  'cosmos': 1,
#  'macrocosm': 1,
#  'system.\n': 1,
#  'Initially,': 1,
#  'was': 2,
#  'imparted': 1,
#  'Adiyogi': 2,
#  '(the': 1,
#  'first': 1,
#  'yogi),': 1,
#  'Shiva,': 1,
#  '15,000': 1,
#  'years': 1,
#  'ago.': 1,
#  'It': 2,
#  'who': 2,
#  'introduced': 1,
#  'humanity': 1,
#  'idea': 1,
#  'can': 1,
#  'evolve': 1,
#  'beyond': 1,
#  'one’s': 1,
#  'present': 1,
#  'level': 1,
#  'existence.': 1,
#  'He': 1,
#  'poured': 1,
#  'his': 1,
#  'knowing': 1,
#  'legendary': 1,
#  'Sapta': 1,
#  'Rishis,': 1,
#  'seven': 1,
#  'sages,': 1,
#  'took': 1,
#  'tremendous': 1,
#  'possibility': 1,
#  'offered': 1,
#  'science': 2,
#  'various': 1,
#  'parts': 1,
#  'world,': 1,
#  'including': 1,
#  'Asia,': 1,
#  'Persia,': 1,
#  'northern': 1,
#  'Africa,': 1,
#  'South': 1,
#  'America.': 1,
#  'fundamental': 1,
#  'yet': 1,
#  'sophisticated': 1,
#  'elevating': 1,
#  'consciousness': 1,
#  'source': 1,
#  'world’s': 1,
#  'spiritual': 1,
#  'traditions,': 1,
#  'predating': 1,
#  'religion': 1,
#  'many': 1,
#  'years.': 1}

# %%
#clean your data

wordQuant.pop("")
wordQuant.pop("\n")
# Out:
# 5

# %%
max(wordQuant.values())
# Out:
# 18

# %%
for word, freq in wordQuant.items():
    #if freq == 19:
    if freq == max(wordQuant.values()):
        print(word)
# Out:
# the

# %% [markdown]
# ### Regular Expressions (re)
# This is another package that allows you to navigate, and edit things such as strings. There are some key methods that we should know
# - find()
# - findall(): returns a list of all the matches of the pattern we specified found in the source
# - replace()

# %% [markdown]
# Return all non-overlapping matches of pattern in string, as a list of strings or tuples. The string is scanned left-to-right, and matches are returned in the order found. Empty matches are included in the result.
#
# - replace()
#
# - search():
#
# Scan through string looking for the first location where the regular expression pattern produces a match, and return a corresponding Match. Return None if no position in the string matches the pattern; note that this is different from finding a zero-length match at some point in the string.

# %%
#import the regular expressions package

import re

# %%
# import nyt_restaurantRevolution.txt to a string

with open("data/nyt_restaurantRevolution.txt", "r", encoding = "utf8") as f:
    #print(f.read())

    myString = f.read()

myString
# Out:
# "\\f0\\fs40 \\cf2 \\expnd0\\expndtw0\\kerning0\nLike so many other chefs, I was drawn to the restaurant business because it is exciting. I ignored its dysfunction and accepted that I\\'92d forgo higher education, financial stability and holidays with family in order to share my craft with others.\\\nAll it took was a pandemic, an enormous wave of inflation and an impossibly tight job market to force me and many others to burrow to the very core of what a restaurant does for its guests, workers and community and redefine it from the ground up.\\\nThis is the silver lining of the pandemic and the never-ending economic uncertainty that has ensued: More places are finally figuring out how to make this business an actual business.\\\n\\pard\\pardeftab720\\partightenfactor0\n\\cf2 The start of my story is a typical one. I gleefully started skipping school to work in kitchens at 15, then shipped off to New York to experience all kinds of \\'93character building\\'94 abuse, and by my early 30s, I had made it in San Francisco as an executive chef \\'85 which meant 80-hour workweeks while barely scraping by.\\\n\n\\f1\\fs32 \\cf3 \\\n\\pard\\pardeftab720\\sa300\\partightenfactor0\n\n\\f0\\fs40 \\cf2 I eventually struck out on my own, deciding to play it safe by opening a restaurant with a normal business model. And as is usually the case, \\cf4 \\ul \\ulc4 normal sucked\\cf2 \\ulnone . Our 80 seats were full every night, employing great folks and serving great food and cocktails \\'97 and sweating our $11,000 rent and roughly $90,000 payroll each month. Structurally, our mission to price affordably had landed us in the death zone: full service yet unable to charge fine-dining prices. The anxiety was weapons grade.\\\nThe standard model for a business almost all of us engage with regularly, \\cf4 \\ul \\ulc4 the one we frequently post our own reviews about\\cf2 \\ulnone , has barely worked for a majority of the \\cf4 \\ul \\ulc4 more than 12 million people\\cf2 \\ulnone  it employs. The restaurant industry accounts for some 4 percent of the G.D.P. in the United States but has been stuck in a deeply flawed business model with \\cf4 \\ul \\ulc4 sadly outdated\\cf2 \\ulnone  practices. The pandemic only brought this reality to the center of the plate and made it something we couldn\\'92t push aside anymore.\n\\fs34 \\\n\\pard\\pardeftab720\\sa300\\partightenfactor0\n\n\\fs40 \\cf2 Yet I find deep meaning and purpose in the work in a way I can\\'92t quite put my finger on, something to do with providing for other human beings.\\\nThen it was March 2020. I was sitting at the redwood table I\\'92d recently finished staining for my barely year-old restaurant, digesting the news that the night\\'92s party of 18 had just canceled. Something called Covid-19 was causing our bookings to disappear. It was also emptying grocery shelves; a friend asked to buy three flats of eggs. Right next to me sat a stack of invoices.\\\n\\pard\\pardeftab720\\partightenfactor0\n\\cf2 My egg friend also desperately needed paper towels, since evidently grocery stores were out of those, too. I took his order, took this as a sign and flipped our space \\cf4 \\ul into a general store\\cf2 \\ulnone . It took off, we even hired people, and that stack of bills was soon paid, which felt like a triumph. But after five chaotic months of repackaging bulk food, the supply chain adjusted, shelves at traditional grocers refilled, and the floor fell out from underneath us again, only more so. On Aug. 11, 2020, almost the same day Congress decided it would go on recess without any agreement for additional small business aid, I made the gut-wrenching decision to close, adding me and my staff to the country\\'92s devastating unemployment statistics.\n\\f2\\fs32 \\cf0 \\\n\\pard\\pardeftab720\\qc\\partightenfactor0\n\n\\f1 \\cf3 \\\n\\pard\\pardeftab720\\sa300\\partightenfactor0\n\n\\f0\\fs40 \\cf2 I needed to find some work or to create some, and I remembered a crazy idea I had years  ...

# %%
myString.strip()
# Out:
# "\\f0\\fs40 \\cf2 \\expnd0\\expndtw0\\kerning0\nLike so many other chefs, I was drawn to the restaurant business because it is exciting. I ignored its dysfunction and accepted that I\\'92d forgo higher education, financial stability and holidays with family in order to share my craft with others.\\\nAll it took was a pandemic, an enormous wave of inflation and an impossibly tight job market to force me and many others to burrow to the very core of what a restaurant does for its guests, workers and community and redefine it from the ground up.\\\nThis is the silver lining of the pandemic and the never-ending economic uncertainty that has ensued: More places are finally figuring out how to make this business an actual business.\\\n\\pard\\pardeftab720\\partightenfactor0\n\\cf2 The start of my story is a typical one. I gleefully started skipping school to work in kitchens at 15, then shipped off to New York to experience all kinds of \\'93character building\\'94 abuse, and by my early 30s, I had made it in San Francisco as an executive chef \\'85 which meant 80-hour workweeks while barely scraping by.\\\n\n\\f1\\fs32 \\cf3 \\\n\\pard\\pardeftab720\\sa300\\partightenfactor0\n\n\\f0\\fs40 \\cf2 I eventually struck out on my own, deciding to play it safe by opening a restaurant with a normal business model. And as is usually the case, \\cf4 \\ul \\ulc4 normal sucked\\cf2 \\ulnone . Our 80 seats were full every night, employing great folks and serving great food and cocktails \\'97 and sweating our $11,000 rent and roughly $90,000 payroll each month. Structurally, our mission to price affordably had landed us in the death zone: full service yet unable to charge fine-dining prices. The anxiety was weapons grade.\\\nThe standard model for a business almost all of us engage with regularly, \\cf4 \\ul \\ulc4 the one we frequently post our own reviews about\\cf2 \\ulnone , has barely worked for a majority of the \\cf4 \\ul \\ulc4 more than 12 million people\\cf2 \\ulnone  it employs. The restaurant industry accounts for some 4 percent of the G.D.P. in the United States but has been stuck in a deeply flawed business model with \\cf4 \\ul \\ulc4 sadly outdated\\cf2 \\ulnone  practices. The pandemic only brought this reality to the center of the plate and made it something we couldn\\'92t push aside anymore.\n\\fs34 \\\n\\pard\\pardeftab720\\sa300\\partightenfactor0\n\n\\fs40 \\cf2 Yet I find deep meaning and purpose in the work in a way I can\\'92t quite put my finger on, something to do with providing for other human beings.\\\nThen it was March 2020. I was sitting at the redwood table I\\'92d recently finished staining for my barely year-old restaurant, digesting the news that the night\\'92s party of 18 had just canceled. Something called Covid-19 was causing our bookings to disappear. It was also emptying grocery shelves; a friend asked to buy three flats of eggs. Right next to me sat a stack of invoices.\\\n\\pard\\pardeftab720\\partightenfactor0\n\\cf2 My egg friend also desperately needed paper towels, since evidently grocery stores were out of those, too. I took his order, took this as a sign and flipped our space \\cf4 \\ul into a general store\\cf2 \\ulnone . It took off, we even hired people, and that stack of bills was soon paid, which felt like a triumph. But after five chaotic months of repackaging bulk food, the supply chain adjusted, shelves at traditional grocers refilled, and the floor fell out from underneath us again, only more so. On Aug. 11, 2020, almost the same day Congress decided it would go on recess without any agreement for additional small business aid, I made the gut-wrenching decision to close, adding me and my staff to the country\\'92s devastating unemployment statistics.\n\\f2\\fs32 \\cf0 \\\n\\pard\\pardeftab720\\qc\\partightenfactor0\n\n\\f1 \\cf3 \\\n\\pard\\pardeftab720\\sa300\\partightenfactor0\n\n\\f0\\fs40 \\cf2 I needed to find some work or to create some, and I remembered a crazy idea I had years  ...

# %%
# get all the instances of the word "restaurant"

re.findall("restaurant", myString)
# Out:
# ['restaurant',
#  'restaurant',
#  'restaurant',
#  'restaurant',
#  'restaurant',
#  'restaurant',
#  'restaurant',
#  'restaurant',
#  'restaurant',
#  'restaurant',
#  'restaurant']

# %%
#what type is the resulting findall() method
type(re.findall("restaurant", myString))
# Out:
# list

# %%
#find the number of instances of the word 'restaurant'

rLyst = re.findall("restaurant", myString)

len(rLyst)
# Out:
# 11

# %% [markdown]
# #### wildcards / regex symbols
# * \d : any digit
# * \s : any whitespace character
# * \S : any non-whitespace character
# * \w : any alphanumeric character (a-z, A-Z, 0-9, _)
# * \W : any non-alphanumeric character
# * \t : tab characters
# * \n : newline
# * . : any character except the newline character

# %%
#find all the numbers in the .txt file

re.findall("\d+", myString)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/1983746664.py:3: SyntaxWarning: invalid escape sequence '\d'
#   re.findall("\d+", myString)
# ['0',
#  '40',
#  '2',
#  '0',
#  '0',
#  '0',
#  '92',
#  '720',
#  '0',
#  '2',
#  '15',
#  '93',
#  '94',
#  '30',
#  '85',
#  '80',
#  '1',
#  '32',
#  '3',
#  '720',
#  '300',
#  '0',
#  '0',
#  '40',
#  '2',
#  '4',
#  '4',
#  '2',
#  '80',
#  '97',
#  '11',
#  '000',
#  '90',
#  '000',
#  '4',
#  '4',
#  '2',
#  '4',
#  '4',
#  '12',
#  '2',
#  '4',
#  '4',
#  '4',
#  '2',
#  '92',
#  '34',
#  '720',
#  '300',
#  '0',
#  '40',
#  '2',
#  '92',
#  '2020',
#  '92',
#  '92',
#  '18',
#  '19',
#  '720',
#  '0',
#  '2',
#  '4',
#  '2',
#  '11',
#  '2020',
#  '92',
#  '2',
#  '32',
#  '0',
#  '720',
#  '0',
#  '1',
#  '3',
#  '720',
#  '300',
#  '0',
#  '0',
#  '40',
#  '2',
#  '93',
#  '92',
#  '94',
#  '93',
#  '94',
#  '18',
#  '000',
#  '1989',
#  '11',
#  '2020',
#  '4',
#  '2',
#  '88',
#  '165',
#  '92',
#  '720',
#  '0',
#  '2',
#  '92',
#  '4',
#  '2',
#  '92',
#  '720',
#  '0',
#  '1',
#  '32',
#  '3',
#  '720',
#  '300',
#  '0',
#  '0',
#  '40',
#  '2',
#  '35',
#  '92',
#  '92',
#  '15',
#  '92',
#  '20',
#  '720',
#  '0',
#  '2',
#  '92',
#  '85',
#  '4',
#  '2',
#  '92',
#  '15',
#  '92',
#  '2',
#  '32',
#  '0',
#  '720',
#  '0',
#  '1',
#  '3',
#  '720',
#  '300',
#  '0',
#  '0',
#  '40',
#  '2',
#  '92',
#  '4',
#  '2',
#  '4',
#  '2',
#  '92',
#  '92',
#  '4',
#  '2',
#  '97',
#  '97',
#  '4',
#  '2',
#  '720',
#  '0',
#  '2',
#  '92',
#  '97',
#  '4',
#  '2']

# %%
#find all of the WORDS ONLY 

re.findall("\w+", myString)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/1912602605.py:3: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("\w+", myString)
# ['f0',
#  'fs40',
#  'cf2',
#  'expnd0',
#  'expndtw0',
#  'kerning0',
#  'Like',
#  'so',
#  'many',
#  'other',
#  'chefs',
#  'I',
#  'was',
#  'drawn',
#  'to',
#  'the',
#  'restaurant',
#  'business',
#  'because',
#  'it',
#  'is',
#  'exciting',
#  'I',
#  'ignored',
#  'its',
#  'dysfunction',
#  'and',
#  'accepted',
#  'that',
#  'I',
#  '92d',
#  'forgo',
#  'higher',
#  'education',
#  'financial',
#  'stability',
#  'and',
#  'holidays',
#  'with',
#  'family',
#  'in',
#  'order',
#  'to',
#  'share',
#  'my',
#  'craft',
#  'with',
#  'others',
#  'All',
#  'it',
#  'took',
#  'was',
#  'a',
#  'pandemic',
#  'an',
#  'enormous',
#  'wave',
#  'of',
#  'inflation',
#  'and',
#  'an',
#  'impossibly',
#  'tight',
#  'job',
#  'market',
#  'to',
#  'force',
#  'me',
#  'and',
#  'many',
#  'others',
#  'to',
#  'burrow',
#  'to',
#  'the',
#  'very',
#  'core',
#  'of',
#  'what',
#  'a',
#  'restaurant',
#  'does',
#  'for',
#  'its',
#  'guests',
#  'workers',
#  'and',
#  'community',
#  'and',
#  'redefine',
#  'it',
#  'from',
#  'the',
#  'ground',
#  'up',
#  'This',
#  'is',
#  'the',
#  'silver',
#  'lining',
#  'of',
#  'the',
#  'pandemic',
#  'and',
#  'the',
#  'never',
#  'ending',
#  'economic',
#  'uncertainty',
#  'that',
#  'has',
#  'ensued',
#  'More',
#  'places',
#  'are',
#  'finally',
#  'figuring',
#  'out',
#  'how',
#  'to',
#  'make',
#  'this',
#  'business',
#  'an',
#  'actual',
#  'business',
#  'pard',
#  'pardeftab720',
#  'partightenfactor0',
#  'cf2',
#  'The',
#  'start',
#  'of',
#  'my',
#  'story',
#  'is',
#  'a',
#  'typical',
#  'one',
#  'I',
#  'gleefully',
#  'started',
#  'skipping',
#  'school',
#  'to',
#  'work',
#  'in',
#  'kitchens',
#  'at',
#  '15',
#  'then',
#  'shipped',
#  'off',
#  'to',
#  'New',
#  'York',
#  'to',
#  'experience',
#  'all',
#  'kinds',
#  'of',
#  '93character',
#  'building',
#  '94',
#  'abuse',
#  'and',
#  'by',
#  'my',
#  'early',
#  '30s',
#  'I',
#  'had',
#  'made',
#  'it',
#  'in',
#  'San',
#  'Francisco',
#  'as',
#  'an',
#  'executive',
#  'chef',
#  '85',
#  'which',
#  'meant',
#  '80',
#  'hour',
#  'workweeks',
#  'while',
#  'barely',
#  'scraping',
#  'by',
#  'f1',
#  'fs32',
#  'cf3',
#  'pard',
#  'pardeftab720',
#  'sa300',
#  'partightenfactor0',
#  'f0',
#  'fs40',
#  'cf2',
#  'I',
#  'eventually',
#  'struck',
#  'out',
#  'on',
#  'my',
#  'own',
#  'deciding',
#  'to',
#  'play',
#  'it',
#  'safe',
#  'by',
#  'opening',
#  'a',
#  'restaurant',
#  'with',
#  'a',
#  'normal',
#  'business',
#  'model',
#  'And',
#  'as',
#  'is',
#  'usually',
#  'the',
#  'case',
#  'cf4',
#  'ul',
#  'ulc4',
#  'normal',
#  'sucked',
#  'cf2',
#  'ulnone',
#  'Our',
#  '80',
#  'seats',
#  'were',
#  'full',
#  'every',
#  'night',
#  'employing',
#  'great',
#  'folks',
#  'and',
#  'serving',
#  'great',
#  'food',
#  'and',
#  'cocktails',
#  '97',
#  'and',
#  'sweating',
#  'our',
#  '11',
#  '000',
#  'rent',
#  'and',
#  'roughly',
#  '90',
#  '000',
#  'payroll',
#  'each',
#  'month',
#  'Structurally',
#  'our',
#  'mission',
#  'to',
#  'price',
#  'affordably',
#  'had',
#  'landed',
#  'us',
#  'in',
#  'the',
#  'death',
#  'zone',
#  'full',
#  'service',
#  'yet',
#  'unable',
#  'to',
#  'charge',
#  'fine',
#  'dining',
#  'prices',
#  'The',
#  'anxiety',
#  'was',
#  'weapons',
#  'grade',
#  'The',
#  'standard',
#  'model',
#  'for',
#  'a',
#  'business',
#  'almost',
#  'all',
#  'of',
#  'us',
#  'engage',
#  'with',
#  'regularly',
#  'cf4',
#  'ul',
#  'ulc4',
#  'the',
#  'one',
#  'we',
#  'frequently',
#  'post',
#  'our',
#  'own',
#  'reviews',
#  'about',
#  'cf2',
#  'ulnone',
#  'has',
#  'barely',
#  'worked',
#  'for',
#  'a',
#  'majority',
#  'of',
#  'the',
#  'cf4',
#  'ul',
#  'ulc4',
#  'more',
#  'than',
#  '12',
#  'million',
#  'people',
#  'cf2',
#  'ulnone',
#  'it',
#  'employs',
#  'The',
#  'restaurant',
#  'industry',
#  'accounts',
#  'for',
#  'some',
#  '4',
#  'percent',
#  'of',
#  'the',
#  'G',
#  'D',
#  'P',
#  'in',
#  'the',
#  'United',
#  'States',
#  'but',
#  'has',
#  'been',
#  'stuck',
#  'in',
#  'a',
#  'deeply',
#  'flawed',
#  'business',
#  'model',
#  'with',
#  'cf4',
#  'ul',
#  'ulc4',
#  'sadly',
#  'outdated',
#  'cf2',
#  'ulnone',
#  'practices',
#  'The',
#  'pandemic',
#  'only',
#  'brought',
#  'this',
#  'reality',
#  'to',
#  'the',
#  'center',
#  'of',
#  'the',
#  'plate',
#  'and',
#  'made',
#  'it',
#  'something',
#  'we',
#  'couldn',
#  '92t',
#  'push',
#  'aside',
#  'anymore',
#  'fs34',
#  'pard',
#  'pardeftab720',
#  'sa300',
#  'partightenfactor0',
#  'fs40',
#  'cf2',
#  'Yet',
#  'I',
#  'find',
#  'deep',
#  'meaning',
#  'and',
#  'purpose',
#  'in',
#  'the',
#  'work',
#  'in',
#  'a',
#  'way',
#  'I',
#  'can',
#  '92t',
#  'quite',
#  'put',
#  'my',
#  'finger',
#  'on',
#  'something',
#  'to',
#  'do',
#  'with',
#  'providing',
#  'for',
#  'other',
#  'human',
#  'beings',
#  'Then',
#  'it',
#  'was',
#  'March',
#  '2020',
#  'I',
#  'was',
#  'sitting',
#  'at',
#  'the',
#  'redwood',
#  'table',
#  'I',
#  '92d',
#  'recently',
#  'finished',
#  'staining',
#  'for',
#  'my',
#  'barely',
#  'year',
#  'old',
#  'restaurant',
#  'digesting',
#  'the',
#  'news',
#  'that',
#  'the',
#  'night',
#  '92s',
#  'party',
#  'of',
#  '18',
#  'had',
#  'just',
#  'canceled',
#  'Something',
#  'called',
#  'Covid',
#  '19',
#  'was',
#  'causing',
#  'our',
#  'bookings',
#  'to',
#  'disappear',
#  'It',
#  'was',
#  'also',
#  'emptying',
#  'grocery',
#  'shelves',
#  'a',
#  'friend',
#  'asked',
#  'to',
#  'buy',
#  'three',
#  'flats',
#  'of',
#  'eggs',
#  'Right',
#  'next',
#  'to',
#  'me',
#  'sat',
#  'a',
#  'stack',
#  'of',
#  'invoices',
#  'pard',
#  'pardeftab720',
#  'partightenfactor0',
#  'cf2',
#  'My',
#  'egg',
#  'friend',
#  'also',
#  'desperately',
#  'needed',
#  'paper',
#  'towels',
#  'since',
#  'evidently',
#  'grocery',
#  'stores',
#  'were',
#  'out',
#  'of',
#  'those',
#  'too',
#  'I',
#  'took',
#  'his',
#  'order',
#  'took',
#  'this',
#  'as',
#  'a',
#  'sign',
#  'and',
#  'flipped',
#  'our',
#  'space',
#  'cf4',
#  'ul',
#  'into',
#  'a',
#  'general',
#  'store',
#  'cf2',
#  'ulnone',
#  'It',
#  'took',
#  'off',
#  'we',
#  'even',
#  'hired',
#  'people',
#  'and',
#  'that',
#  'stack',
#  'of',
#  'bills',
#  'was',
#  'soon',
#  'paid',
#  'which',
#  'felt',
#  'like',
#  'a',
#  'triumph',
#  'But',
#  'after',
#  'five',
#  'chaotic',
#  'months',
#  'of',
#  'repackaging',
#  'bulk',
#  'food',
#  'the',
#  'supply',
#  'chain',
#  'adjusted',
#  'shelves',
#  'at',
#  'traditional',
#  'grocers',
#  'refilled',
#  'and',
#  'the',
#  'floor',
#  'fell',
#  'out',
#  'from',
#  'underneath',
#  'us',
#  'again',
#  'only',
#  'more',
#  'so',
#  'On',
#  'Aug',
#  '11',
#  '2020',
#  'almost',
#  'the',
#  'same',
#  'day',
#  'Congress',
#  'decided',
#  'it',
#  'would',
#  'go',
#  'on',
#  'recess',
#  'without',
#  'any',
#  'agreement',
#  'for',
#  'additional',
#  'small',
#  'business',
#  'aid',
#  'I',
#  'made',
#  'the',
#  'gut',
#  'wrenching',
#  'decision',
#  'to',
#  'close',
#  'adding',
#  'me',
#  'and',
#  'my',
#  'staff',
#  'to',
#  'the',
#  'country',
#  '92s',
#  'devastating',
#  'unemployment',
#  'statistics',
#  'f2',
#  'fs32',
#  'cf0',
#  'pard',
#  'pardeftab720',
#  'qc',
#  'partightenfactor0',
#  'f1',
#  'cf3',
#  'pard',
#  'pardeftab720',
#  'sa300',
#  'partightenfactor0',
#  'f0',
#  'fs40',
#  'cf2',
#  'I',
#  'needed',
#  'to',
#  'find',
#  'some',
#  'work',
#  'or',
#  'to',
#  'create',
#  'some',
#  'and',
#  'I',
#  'remembered',
#  'a',
#  'crazy',
#  'idea',
#  'I',
#  'had',
#  'years',
#  'ago',
#  'while',
#  'driving',
#  'back',
#  'home',
#  'to',
#  'Iowa',
#  'My',
#  'mind',
#  'was',
#  'deep',
#  'in',
#  '93I',
#  '92m',
#  'so',
#  'frustrated',
#  'with',
#  'the',
#  'miserable',
#  'economics',
#  'of',
#  'my',
#  'chosen',
#  'profession',
#  '94',
#  'territory',
#  'as',
#  'I',
#  'passed',
#  'a',
#  'used',
#  'R',
#  'V',
#  'lot',
#  'I',
#  'chuckled',
#  'and',
#  'thought',
#  '93Maybe',
#  'you',
#  'should',
#  'just',
#  'open',
#  'a',
#  'tiny',
#  'private',
#  'dining',
#  'room',
#  '94',
#  'I',
#  'chuckled',
#  'again',
#  'nervously',
#  'as',
#  'I',
#  'recalled',
#  'it',
#  'Then',
#  'I',
#  'did',
#  'some',
#  'back',
#  'of',
#  'the',
#  'envelope',
#  'calculations',
#  'and',
#  'scraped',
#  'together',
#  '18',
#  '000',
#  'to',
#  'buy',
#  'a',
#  '1989',
#  'Volkswagen',
#  'camper',
#  'I',
#  'found',
#  'on',
#  'Craigslist',
#  'I',
#  'renamed',
#  'the',
#  'van',
#  'SuperStella',
#  'and',
#  'rebuilt',
#  'her',
#  'with',
#  'a',
#  'surprisingly',
#  'luxurious',
#  'yes',
#  'really',
#  'dining',
#  'room',
#  'for',
#  'four',
#  'For',
#  '11',
#  'months',
#  'starting',
#  'in',
#  'November',
#  '2020',
#  'cf4',
#  'ul',
#  'SuperStella',
#  'cf2',
#  'ulnone',
#  'served',
#  'two',
#  'Covid',
#  'safe',
#  'seatings',
#  'a',
#  'night',
#  'in',
#  'a',
#  'private',
#  'lot',
#  'that',
#  'had',
#  'a',
#  'commanding',
#  'view',
#  'of',
#  'the',
#  'Bay',
#  'Bridge',
#  'and',
#  'its',
#  'twinkling',
#  'lights',
#  'For',
#  'a',
#  'check',
#  'that',
#  'ranged',
#  'from',
#  '88',
#  'to',
#  '165',
#  'a',
#  'person',
#  'diners',
#  'enjoyed',
#  'a',
#  'glamping',
#  'themed',
#  'menu',
#  'of',
#  'things',
#  'like',
#  'whole',
#  'grilled',
#  'trout',
#  'with',
#  'nasturtium',
#  'butter',
#  'poured',
#  'from',
#  'a',
#  'thermos',
#  'and',
#  'a',
#  'fat',
#  'slice',
#  'of',
#  'grilled',
#  'milk',
#  'bread',
#  'with',
#  'salted',
#  'maple',
#  'butter',
#  'shaved',
#  'over',
#  'it',
#  'for',
#  'dessert',
#  'I',
#  'was',
#  'the',
#  'waiter',
#  'sommelier',
#  'and',
#  'cook',
#  'Not',
#  'only',
#  'did',
#  'I',
#  'get',
#  'tons',
#  'of',
#  'vitamin',
#  'D',
#  'for',
#  'once',
#  'and',
#  'bring',
#  'joy',
#  'to',
#  'some',
#  'lockdown',
#  'fatigued',
#  'diners',
#  'but',
#  'thanks',
#  'to',
#  'the',
#  'fact',
#  'that',
#  'I',
#  'had',
#  'low',
#  'to',
#  'no',
#  'overhead',
#  'I',
#  'was',
#  'also',
#  'making',
#  'a',
#  'comfortable',
#  'living',
#  'for',
#  'the',
#  'first',
#  'time',
#  'in',
#  'my',
#  'career',
#  'Was',
#  'SuperStella',
#  'a',
#  'restaurant',
#  'Technically',
#  'no',
#  'I',
#  '92d',
#  'navigated',
#  'some',
#  'regulatory',
#  'gray',
#  'area',
#  'by',
#  'designating',
#  'it',
#  'as',
#  'catering',
#  'and',
#  'the',
#  'private',
#  'lot',
#  'as',
#  'a',
#  'venue',
#  'It',
#  'would',
#  'be',
#  'only',
#  'temporary',
#  'since',
#  'operating',
#  'longer',
#  'would',
#  'have',
#  'been',
#  'a',
#  'case',
#  'study',
#  'in',
#  'navigating',
#  'bureaucracy',
#  'No',
#  'thanks',
#  'But',
#  'I',
#  'was',
#  'emboldened',
#  'to',
#  'believe',
#  'that',
#  'whatever',
#  'I',
#  'did',
#  'next',
#  'could',
#  'and',
#  'would',
#  'make',
#  'money',
#  'All',
#  'I',
#  'had',
#  'to',
#  'do',
#  'was',
#  'throw',
#  'out',
#  'the',
#  'definition',
#  'of',
#  'how',
#  'a',
#  'restaurant',
#  'normally',
#  'works',
#  'and',
#  'start',
#  'over',
#  'from',
#  'scratch',
#  'pard',
#  'pardeftab720',
#  'partightenfactor0',
#  'cf2',
#  'Fast',
#  'forward',
#  'to',
#  'today',
#  'Most',
#  'days',
#  'you',
#  ...]

# %%
# how many words are there?

len(re.findall("\w+", myString))
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/3101464723.py:3: SyntaxWarning: invalid escape sequence '\w'
#   len(re.findall("\w+", myString))
# 1699

# %%
# let's find all the numeric representations of dollar amounts in the story
# $ means something in regex so we need to escape it if we're just looking for the $ character

re.findall("\$\d+", myString)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/815312845.py:4: SyntaxWarning: invalid escape sequence '\$'
#   re.findall("\$\d+", myString)
# ['$11', '$90', '$18', '$88', '$165', '$20']

# %%
# let's match the dollar amounts along with the word following those amounts

re.findall("\$\d+ \w+", myString)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/4178710076.py:3: SyntaxWarning: invalid escape sequence '\$'
#   re.findall("\$\d+ \w+", myString)
# ['$88 to', '$165 a']

# %%
re.findall("\w+ \$\d+", myString)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/1341351327.py:1: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("\w+ \$\d+", myString)
# ['our $11', 'roughly $90', 'together $18', 'from $88', 'to $165', 'under $20']

# %%
# we're still not matching decimal numbers, so let's do that
# \S matches any non-whitespace character

re.findall("\$\S+ \w+", myString)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/2565869598.py:4: SyntaxWarning: invalid escape sequence '\$'
#   re.findall("\$\S+ \w+", myString)
# ['$11,000 rent',
#  '$90,000 payroll',
#  '$18,000 to',
#  '$88 to',
#  '$165 a',
#  '$20. Our']

# %%
# if you only wanted to match million,

#re.findall("\$\S+ million", myString)

re.findall("\$\S+ rent", myString)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\$'
# <>:5: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/443373379.py:5: SyntaxWarning: invalid escape sequence '\$'
#   re.findall("\$\S+ rent", myString)
# ['$11,000 rent']

# %%
# what if we want to find all words that start with a vowel?
# square brackets in regex does or

re.findall("[aeiouAEIOU]\w+", myString)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/3188283875.py:4: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("[aeiouAEIOU]\w+", myString)
# ['expnd0',
#  'expndtw0',
#  'erning0',
#  'ike',
#  'any',
#  'other',
#  'efs',
#  'as',
#  'awn',
#  'estaurant',
#  'usiness',
#  'ecause',
#  'it',
#  'is',
#  'exciting',
#  'ignored',
#  'its',
#  'unction',
#  'and',
#  'accepted',
#  'at',
#  'orgo',
#  'igher',
#  'education',
#  'inancial',
#  'ability',
#  'and',
#  'olidays',
#  'ith',
#  'amily',
#  'in',
#  'order',
#  'are',
#  'aft',
#  'ith',
#  'others',
#  'All',
#  'it',
#  'ook',
#  'as',
#  'andemic',
#  'an',
#  'enormous',
#  'ave',
#  'of',
#  'inflation',
#  'and',
#  'an',
#  'impossibly',
#  'ight',
#  'ob',
#  'arket',
#  'orce',
#  'and',
#  'any',
#  'others',
#  'urrow',
#  'ery',
#  'ore',
#  'of',
#  'at',
#  'estaurant',
#  'oes',
#  'or',
#  'its',
#  'uests',
#  'orkers',
#  'and',
#  'ommunity',
#  'and',
#  'edefine',
#  'it',
#  'om',
#  'ound',
#  'up',
#  'is',
#  'is',
#  'ilver',
#  'ining',
#  'of',
#  'andemic',
#  'and',
#  'ever',
#  'ending',
#  'economic',
#  'uncertainty',
#  'at',
#  'as',
#  'ensued',
#  'ore',
#  'aces',
#  'are',
#  'inally',
#  'iguring',
#  'out',
#  'ow',
#  'ake',
#  'is',
#  'usiness',
#  'an',
#  'actual',
#  'usiness',
#  'ard',
#  'ardeftab720',
#  'artightenfactor0',
#  'art',
#  'of',
#  'ory',
#  'is',
#  'ical',
#  'one',
#  'eefully',
#  'arted',
#  'ipping',
#  'ool',
#  'ork',
#  'in',
#  'itchens',
#  'at',
#  'en',
#  'ipped',
#  'off',
#  'ew',
#  'ork',
#  'experience',
#  'all',
#  'inds',
#  'of',
#  'aracter',
#  'uilding',
#  'abuse',
#  'and',
#  'early',
#  'ad',
#  'ade',
#  'it',
#  'in',
#  'an',
#  'ancisco',
#  'as',
#  'an',
#  'executive',
#  'ef',
#  'ich',
#  'eant',
#  'our',
#  'orkweeks',
#  'ile',
#  'arely',
#  'aping',
#  'ard',
#  'ardeftab720',
#  'a300',
#  'artightenfactor0',
#  'eventually',
#  'uck',
#  'out',
#  'on',
#  'own',
#  'eciding',
#  'ay',
#  'it',
#  'afe',
#  'opening',
#  'estaurant',
#  'ith',
#  'ormal',
#  'usiness',
#  'odel',
#  'And',
#  'as',
#  'is',
#  'usually',
#  'ase',
#  'ul',
#  'ulc4',
#  'ormal',
#  'ucked',
#  'ulnone',
#  'Our',
#  'eats',
#  'ere',
#  'ull',
#  'every',
#  'ight',
#  'employing',
#  'eat',
#  'olks',
#  'and',
#  'erving',
#  'eat',
#  'ood',
#  'and',
#  'ocktails',
#  'and',
#  'eating',
#  'our',
#  'ent',
#  'and',
#  'oughly',
#  'ayroll',
#  'each',
#  'onth',
#  'ucturally',
#  'our',
#  'ission',
#  'ice',
#  'affordably',
#  'ad',
#  'anded',
#  'us',
#  'in',
#  'eath',
#  'one',
#  'ull',
#  'ervice',
#  'et',
#  'unable',
#  'arge',
#  'ine',
#  'ining',
#  'ices',
#  'anxiety',
#  'as',
#  'eapons',
#  'ade',
#  'andard',
#  'odel',
#  'or',
#  'usiness',
#  'almost',
#  'all',
#  'of',
#  'us',
#  'engage',
#  'ith',
#  'egularly',
#  'ul',
#  'ulc4',
#  'one',
#  'equently',
#  'ost',
#  'our',
#  'own',
#  'eviews',
#  'about',
#  'ulnone',
#  'as',
#  'arely',
#  'orked',
#  'or',
#  'ajority',
#  'of',
#  'ul',
#  'ulc4',
#  'ore',
#  'an',
#  'illion',
#  'eople',
#  'ulnone',
#  'it',
#  'employs',
#  'estaurant',
#  'industry',
#  'accounts',
#  'or',
#  'ome',
#  'ercent',
#  'of',
#  'in',
#  'United',
#  'ates',
#  'ut',
#  'as',
#  'een',
#  'uck',
#  'in',
#  'eeply',
#  'awed',
#  'usiness',
#  'odel',
#  'ith',
#  'ul',
#  'ulc4',
#  'adly',
#  'outdated',
#  'ulnone',
#  'actices',
#  'andemic',
#  'only',
#  'ought',
#  'is',
#  'eality',
#  'enter',
#  'of',
#  'ate',
#  'and',
#  'ade',
#  'it',
#  'omething',
#  'ouldn',
#  'ush',
#  'aside',
#  'anymore',
#  'ard',
#  'ardeftab720',
#  'a300',
#  'artightenfactor0',
#  'et',
#  'ind',
#  'eep',
#  'eaning',
#  'and',
#  'urpose',
#  'in',
#  'ork',
#  'in',
#  'ay',
#  'an',
#  'uite',
#  'ut',
#  'inger',
#  'on',
#  'omething',
#  'ith',
#  'oviding',
#  'or',
#  'other',
#  'uman',
#  'eings',
#  'en',
#  'it',
#  'as',
#  'arch',
#  'as',
#  'itting',
#  'at',
#  'edwood',
#  'able',
#  'ecently',
#  'inished',
#  'aining',
#  'or',
#  'arely',
#  'ear',
#  'old',
#  'estaurant',
#  'igesting',
#  'ews',
#  'at',
#  'ight',
#  'arty',
#  'of',
#  'ad',
#  'ust',
#  'anceled',
#  'omething',
#  'alled',
#  'ovid',
#  'as',
#  'ausing',
#  'our',
#  'ookings',
#  'isappear',
#  'It',
#  'as',
#  'also',
#  'emptying',
#  'ocery',
#  'elves',
#  'iend',
#  'asked',
#  'uy',
#  'ee',
#  'ats',
#  'of',
#  'eggs',
#  'ight',
#  'ext',
#  'at',
#  'ack',
#  'of',
#  'invoices',
#  'ard',
#  'ardeftab720',
#  'artightenfactor0',
#  'egg',
#  'iend',
#  'also',
#  'esperately',
#  'eeded',
#  'aper',
#  'owels',
#  'ince',
#  'evidently',
#  'ocery',
#  'ores',
#  'ere',
#  'out',
#  'of',
#  'ose',
#  'oo',
#  'ook',
#  'is',
#  'order',
#  'ook',
#  'is',
#  'as',
#  'ign',
#  'and',
#  'ipped',
#  'our',
#  'ace',
#  'ul',
#  'into',
#  'eneral',
#  'ore',
#  'ulnone',
#  'It',
#  'ook',
#  'off',
#  'even',
#  'ired',
#  'eople',
#  'and',
#  'at',
#  'ack',
#  'of',
#  'ills',
#  'as',
#  'oon',
#  'aid',
#  'ich',
#  'elt',
#  'ike',
#  'iumph',
#  'ut',
#  'after',
#  'ive',
#  'aotic',
#  'onths',
#  'of',
#  'epackaging',
#  'ulk',
#  'ood',
#  'upply',
#  'ain',
#  'adjusted',
#  'elves',
#  'at',
#  'aditional',
#  'ocers',
#  'efilled',
#  'and',
#  'oor',
#  'ell',
#  'out',
#  'om',
#  'underneath',
#  'us',
#  'again',
#  'only',
#  'ore',
#  'On',
#  'Aug',
#  'almost',
#  'ame',
#  'ay',
#  'ongress',
#  'ecided',
#  'it',
#  'ould',
#  'on',
#  'ecess',
#  'ithout',
#  'any',
#  'agreement',
#  'or',
#  'additional',
#  'all',
#  'usiness',
#  'aid',
#  'ade',
#  'ut',
#  'enching',
#  'ecision',
#  'ose',
#  'adding',
#  'and',
#  'aff',
#  'ountry',
#  'evastating',
#  'unemployment',
#  'atistics',
#  'ard',
#  'ardeftab720',
#  'artightenfactor0',
#  'ard',
#  'ardeftab720',
#  'a300',
#  'artightenfactor0',
#  'eeded',
#  'ind',
#  'ome',
#  'ork',
#  'or',
#  'eate',
#  'ome',
#  'and',
#  'emembered',
#  'azy',
#  'idea',
#  'ad',
#  'ears',
#  'ago',
#  'ile',
#  'iving',
#  'ack',
#  'ome',
#  'Iowa',
#  'ind',
#  'as',
#  'eep',
#  'in',
#  'ustrated',
#  'ith',
#  'iserable',
#  'economics',
#  'of',
#  'osen',
#  'ofession',
#  'erritory',
#  'as',
#  'assed',
#  'used',
#  'ot',
#  'uckled',
#  'and',
#  'ought',
#  'aybe',
#  'ou',
#  'ould',
#  'ust',
#  'open',
#  'iny',
#  'ivate',
#  'ining',
#  'oom',
#  'uckled',
#  'again',
#  'ervously',
#  'as',
#  'ecalled',
#  'it',
#  'en',
#  'id',
#  'ome',
#  'ack',
#  'of',
#  'envelope',
#  'alculations',
#  'and',
#  'aped',
#  'ogether',
#  'uy',
#  'olkswagen',
#  'amper',
#  'ound',
#  'on',
#  'aigslist',
#  'enamed',
#  'an',
#  'uperStella',
#  'and',
#  'ebuilt',
#  'er',
#  'ith',
#  'urprisingly',
#  'uxurious',
#  'es',
#  'eally',
#  'ining',
#  'oom',
#  'or',
#  'our',
#  'or',
#  'onths',
#  'arting',
#  'in',
#  'ovember',
#  'ul',
#  'uperStella',
#  'ulnone',
#  'erved',
#  'ovid',
#  'afe',
#  'eatings',
#  'ight',
#  'in',
#  'ivate',
#  'ot',
#  'at',
#  'ad',
#  'ommanding',
#  'iew',
#  'of',
#  'ay',
#  'idge',
#  'and',
#  'its',
#  'inkling',
#  'ights',
#  'or',
#  'eck',
#  'at',
#  'anged',
#  'om',
#  'erson',
#  'iners',
#  'enjoyed',
#  'amping',
#  'emed',
#  'enu',
#  'of',
#  'ings',
#  'ike',
#  'ole',
#  'illed',
#  'out',
#  'ith',
#  'asturtium',
#  'utter',
#  'oured',
#  'om',
#  'ermos',
#  'and',
#  'at',
#  'ice',
#  'of',
#  'illed',
#  'ilk',
#  'ead',
#  'ith',
#  'alted',
#  'aple',
#  'utter',
#  'aved',
#  'over',
#  'it',
#  'or',
#  'essert',
#  'as',
#  'aiter',
#  'ommelier',
#  'and',
#  'ook',
#  'ot',
#  'only',
#  'id',
#  'et',
#  'ons',
#  'of',
#  'itamin',
#  'or',
#  'once',
#  'and',
#  'ing',
#  'oy',
#  'ome',
#  'ockdown',
#  'atigued',
#  'iners',
#  'ut',
#  'anks',
#  'act',
#  'at',
#  'ad',
#  'ow',
#  'overhead',
#  'as',
#  'also',
#  'aking',
#  'omfortable',
#  'iving',
#  'or',
#  'irst',
#  'ime',
#  'in',
#  'areer',
#  'as',
#  'uperStella',
#  'estaurant',
#  'echnically',
#  'avigated',
#  'ome',
#  'egulatory',
#  'ay',
#  'area',
#  'esignating',
#  'it',
#  'as',
#  'atering',
#  'and',
#  'ivate',
#  'ot',
#  'as',
#  'enue',
#  'It',
#  'ould',
#  'only',
#  'emporary',
#  'ince',
#  'operating',
#  'onger',
#  'ould',
#  'ave',
#  'een',
#  'ase',
#  'udy',
#  'in',
#  'avigating',
#  'ureaucracy',
#  'anks',
#  'ut',
#  'as',
#  'emboldened',
#  'elieve',
#  'at',
#  'atever',
#  'id',
#  'ext',
#  'ould',
#  'and',
#  'ould',
#  'ake',
#  'oney',
#  'All',
#  'ad',
#  'as',
#  'ow',
#  'out',
#  'efinition',
#  'of',
#  'ow',
#  'estaurant',
#  'ormally',
#  'orks',
#  'and',
#  'art',
#  'over',
#  'om',
#  'atch',
#  'ard',
#  'ardeftab720',
#  'artightenfactor0',
#  'ast',
#  'orward',
#  'oday',
#  'ost',
#  'ays',
#  'ou',
#  'ind',
#  'at',
#  'ul',
#  'ew',
#  'asta',
#  'op',
#  'ulnone',
#  'in',
#  'esidential',
#  'eighborhood',
#  'on',
#  'est',
#  'ide',
#  'of',
#  'an',
#  'ancisco',
#  'ere',
#  'ethought',
#  'etty',
#  'uch',
#  'everything',
#  'in',
#  'order',
#  'eate',
#  'ustainable',
#  'usiness',
#  'odel',
#  'ard',
#  'ardeftab720',
#  'artightenfactor0',
#  'ard',
#  'ardeftab720',
#  'a300',
#  'artightenfactor0',
#  'andard',
#  'estaurant',
#  'ogic',
#  'ictates',
#  'at',
#  'our',
#  'ining',
#  'oom',
#  'as',
#  'ig',
#  'as',
#  'ossible',
#  'ut',
#  'ut',
#  'ours',
#  'in',
#  'alf',
#  'ust',
#  'eats',
#  'usiness',
#  'as',
#  'an',
#  'additional',
#  'eg',
#  'and',
#  'on',
#  'etail',
#  'op',
#  'at',
#  'is',
#  'open',
#  'all',
#  'ay',
#  'elling',
#  'eshly',
#  'ade',
#  'astas',
#  'auces',
#  'and',
#  'igh',
#  'end',
#  'antry',
#  'items',
#  'all',
#  'of',
#  'it',
#  'epared',
#  'and',
#  'urated',
#  'or',
#  'eople',
#  'ake',
#  'easy',
#  'inners',
#  'at',
#  'ome',
#  'Our',
#  'onsistent',
#  'etail',
#  'affic',
#  'alances',
#  'ost',
#  'easonal',
#  'ups',
#  'and',
#  'owns',
#  'en',
#  'oung',
#  'iners',
#  'are',
#  'at',
#  'urning',
#  'an',
#  'amilies',
#  'ill',
#  'ing',
#  'ab',
#  'ucatini',
#  'and',
#  'olive',
#  'oil',
#  'anted',
#  'inuscule',
#  'ining',
#  'oom',
#  'eans',
#  'assive',
#  'iday',
#  'ight',
#  'ales',
#  'ut',
#  'at',
#  'elcome',
#  'ade',
#  'off',
#  'or',
#  'etter',
#  'onsistency',
#  'oughout',
#  'eek',
#  'and',
#  'at',
#  'onsistency',
#  'ives',
#  'us',
#  'eedom',
#  'operate',
#  'ith',
#  'ess',
#  'omplexity',
#  'and',
#  'ewer',
#  'oving',
#  'arts',
#  'Our',
#  'estaurant',
#  'is',
#  'alk',
#  'in',
#  'only',
#  'on',
#  'ay',
#  'an',
#  'online',
#  'eservation',
#  'atform',
#  'or',
#  'ose',
#  'oney',
#  'on',
#  'ows',
#  'Our',
#  'iny',
#  'enu',
#  'is',
#  'efficient',
#  'and',
#  'inimizes',
#  'aste',
#  'Our',
#  'oduct',
#  'asta',
#  'is',
#  'affordable',
#  'enough',
#  'eep',
#  'ofit',
#  'argins',
#  'ufficient',
#  'even',
#  'uring',
#  'inflationary',
#  'eriods',
#  'ost',
#  'important',
#  'uests',
#  'order',
#  'at',
#  'ont',
#  'oor',
#  'ith',
#  'ost',
#  'efore',
#  'eing',
#  'ointed',
#  'eir',
#  'ully',
#  'et',
#  'able',
#  'ich',
#  'eliminates',
#  'inutes',
#  'of',
#  'ofit',
#  'illing',
#  'ead',
#  'ime',
#  'at',
#  'eginning',
#  'of',
#  'each',
#  'eal',
#  'It',
#  'ecoming',
#  'ommon',
#  'or',
#  'us',
#  'ore',
#  'an',
#  'our',
#  'urns',
#  'on',
#  'able',
#  'at',
#  'ight',
#  'aster',
#  'urn',
#  'ables',
#  'onger',
#  'our',
#  'ales',
#  'are',
#  'ore',
#  'ith',
#  'ess',
#  ...]

# %%
# we need a way to say "beginning of a word"
# \\b is the symbol for "word boundary"

re.findall("\\b[aeiouAEIOU]\w+", myString)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/3216638555.py:4: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("\\b[aeiouAEIOU]\w+", myString)
# ['expnd0',
#  'expndtw0',
#  'other',
#  'it',
#  'is',
#  'exciting',
#  'ignored',
#  'its',
#  'and',
#  'accepted',
#  'education',
#  'and',
#  'in',
#  'order',
#  'others',
#  'All',
#  'it',
#  'an',
#  'enormous',
#  'of',
#  'inflation',
#  'and',
#  'an',
#  'impossibly',
#  'and',
#  'others',
#  'of',
#  'its',
#  'and',
#  'and',
#  'it',
#  'up',
#  'is',
#  'of',
#  'and',
#  'ending',
#  'economic',
#  'uncertainty',
#  'ensued',
#  'are',
#  'out',
#  'an',
#  'actual',
#  'of',
#  'is',
#  'one',
#  'in',
#  'at',
#  'off',
#  'experience',
#  'all',
#  'of',
#  'abuse',
#  'and',
#  'early',
#  'it',
#  'in',
#  'as',
#  'an',
#  'executive',
#  'eventually',
#  'out',
#  'on',
#  'own',
#  'it',
#  'opening',
#  'And',
#  'as',
#  'is',
#  'usually',
#  'ul',
#  'ulc4',
#  'ulnone',
#  'Our',
#  'every',
#  'employing',
#  'and',
#  'and',
#  'and',
#  'our',
#  'and',
#  'each',
#  'our',
#  'affordably',
#  'us',
#  'in',
#  'unable',
#  'anxiety',
#  'almost',
#  'all',
#  'of',
#  'us',
#  'engage',
#  'ul',
#  'ulc4',
#  'one',
#  'our',
#  'own',
#  'about',
#  'ulnone',
#  'of',
#  'ul',
#  'ulc4',
#  'ulnone',
#  'it',
#  'employs',
#  'industry',
#  'accounts',
#  'of',
#  'in',
#  'United',
#  'in',
#  'ul',
#  'ulc4',
#  'outdated',
#  'ulnone',
#  'only',
#  'of',
#  'and',
#  'it',
#  'aside',
#  'anymore',
#  'and',
#  'in',
#  'in',
#  'on',
#  'other',
#  'it',
#  'at',
#  'old',
#  'of',
#  'our',
#  'It',
#  'also',
#  'emptying',
#  'asked',
#  'of',
#  'eggs',
#  'of',
#  'invoices',
#  'egg',
#  'also',
#  'evidently',
#  'out',
#  'of',
#  'order',
#  'as',
#  'and',
#  'our',
#  'ul',
#  'into',
#  'ulnone',
#  'It',
#  'off',
#  'even',
#  'and',
#  'of',
#  'after',
#  'of',
#  'adjusted',
#  'at',
#  'and',
#  'out',
#  'underneath',
#  'us',
#  'again',
#  'only',
#  'On',
#  'Aug',
#  'almost',
#  'it',
#  'on',
#  'any',
#  'agreement',
#  'additional',
#  'aid',
#  'adding',
#  'and',
#  'unemployment',
#  'or',
#  'and',
#  'idea',
#  'ago',
#  'Iowa',
#  'in',
#  'economics',
#  'of',
#  'as',
#  'used',
#  'and',
#  'open',
#  'again',
#  'as',
#  'it',
#  'of',
#  'envelope',
#  'and',
#  'on',
#  'and',
#  'in',
#  'ul',
#  'ulnone',
#  'in',
#  'of',
#  'and',
#  'its',
#  'enjoyed',
#  'of',
#  'and',
#  'of',
#  'over',
#  'it',
#  'and',
#  'only',
#  'of',
#  'once',
#  'and',
#  'overhead',
#  'also',
#  'in',
#  'area',
#  'it',
#  'as',
#  'and',
#  'as',
#  'It',
#  'only',
#  'operating',
#  'in',
#  'emboldened',
#  'and',
#  'All',
#  'out',
#  'of',
#  'and',
#  'over',
#  'at',
#  'ul',
#  'ulnone',
#  'in',
#  'on',
#  'of',
#  'everything',
#  'in',
#  'order',
#  'as',
#  'as',
#  'ours',
#  'in',
#  'an',
#  'additional',
#  'on',
#  'is',
#  'open',
#  'all',
#  'and',
#  'end',
#  'items',
#  'all',
#  'of',
#  'it',
#  'and',
#  'easy',
#  'at',
#  'Our',
#  'ups',
#  'and',
#  'are',
#  'at',
#  'and',
#  'olive',
#  'oil',
#  'off',
#  'and',
#  'us',
#  'operate',
#  'and',
#  'Our',
#  'is',
#  'in',
#  'only',
#  'an',
#  'online',
#  'or',
#  'on',
#  'Our',
#  'is',
#  'efficient',
#  'and',
#  'Our',
#  'is',
#  'affordable',
#  'enough',
#  'even',
#  'inflationary',
#  'important',
#  'order',
#  'at',
#  'eliminates',
#  'of',
#  'at',
#  'of',
#  'each',
#  'It',
#  'us',
#  'on',
#  'at',
#  'our',
#  'are',
#  'our',
#  'are',
#  'enable',
#  'us',
#  'and',
#  'on',
#  'our',
#  'at',
#  'everyone',
#  'is',
#  'almost',
#  'all',
#  'of',
#  'our',
#  'are',
#  'under',
#  'Our',
#  'is',
#  'and',
#  'even',
#  'am',
#  'only',
#  'occasionally',
#  'Admittedly',
#  'everyone',
#  'is',
#  'into',
#  'incidents',
#  'about',
#  'our',
#  'and',
#  'indestructible',
#  'ul',
#  'on',
#  'ulnone',
#  'and',
#  'occasionally',
#  'overpriced',
#  'even',
#  'if',
#  'eat',
#  'Once',
#  'in',
#  'opinion',
#  'about',
#  'our',
#  'is',
#  'of',
#  'is',
#  'away',
#  'outdated',
#  'of',
#  'and',
#  'eventually',
#  'evolve',
#  'into',
#  'an',
#  'all',
#  'in',
#  'employees',
#  'into',
#  'around',
#  'ul',
#  'ulnone',
#  'or',
#  'entire',
#  'up',
#  'and',
#  'ul',
#  'ulnone',
#  'instead',
#  'of',
#  'everything',
#  'everyone',
#  'used',
#  'ul',
#  'offbeat',
#  'ulnone',
#  'Embrace',
#  'it',
#  'of',
#  'is',
#  'us',
#  'and',
#  'experiments',
#  'as',
#  'in',
#  'And',
#  'as',
#  'even',
#  'in',
#  'Iowa',
#  'ul',
#  'an',
#  'excellent',
#  'ulnone',
#  'expectations',
#  'is',
#  'or',
#  'Instagrammable',
#  'it',
#  'of',
#  'as',
#  'and',
#  'over',
#  'If',
#  'and',
#  'all',
#  'our',
#  'in',
#  'industry',
#  'as',
#  'ul',
#  'of',
#  'our',
#  'and',
#  'economy',
#  'ulnone']

# %%
# with [] you can also do ranges
# \\b works at the beginning and end of a word

re.findall("\\b[a-zA-Z]+\\b", myString)
# Out:
# ['Like',
#  'so',
#  'many',
#  'other',
#  'chefs',
#  'I',
#  'was',
#  'drawn',
#  'to',
#  'the',
#  'restaurant',
#  'business',
#  'because',
#  'it',
#  'is',
#  'exciting',
#  'I',
#  'ignored',
#  'its',
#  'dysfunction',
#  'and',
#  'accepted',
#  'that',
#  'I',
#  'forgo',
#  'higher',
#  'education',
#  'financial',
#  'stability',
#  'and',
#  'holidays',
#  'with',
#  'family',
#  'in',
#  'order',
#  'to',
#  'share',
#  'my',
#  'craft',
#  'with',
#  'others',
#  'All',
#  'it',
#  'took',
#  'was',
#  'a',
#  'pandemic',
#  'an',
#  'enormous',
#  'wave',
#  'of',
#  'inflation',
#  'and',
#  'an',
#  'impossibly',
#  'tight',
#  'job',
#  'market',
#  'to',
#  'force',
#  'me',
#  'and',
#  'many',
#  'others',
#  'to',
#  'burrow',
#  'to',
#  'the',
#  'very',
#  'core',
#  'of',
#  'what',
#  'a',
#  'restaurant',
#  'does',
#  'for',
#  'its',
#  'guests',
#  'workers',
#  'and',
#  'community',
#  'and',
#  'redefine',
#  'it',
#  'from',
#  'the',
#  'ground',
#  'up',
#  'This',
#  'is',
#  'the',
#  'silver',
#  'lining',
#  'of',
#  'the',
#  'pandemic',
#  'and',
#  'the',
#  'never',
#  'ending',
#  'economic',
#  'uncertainty',
#  'that',
#  'has',
#  'ensued',
#  'More',
#  'places',
#  'are',
#  'finally',
#  'figuring',
#  'out',
#  'how',
#  'to',
#  'make',
#  'this',
#  'business',
#  'an',
#  'actual',
#  'business',
#  'pard',
#  'The',
#  'start',
#  'of',
#  'my',
#  'story',
#  'is',
#  'a',
#  'typical',
#  'one',
#  'I',
#  'gleefully',
#  'started',
#  'skipping',
#  'school',
#  'to',
#  'work',
#  'in',
#  'kitchens',
#  'at',
#  'then',
#  'shipped',
#  'off',
#  'to',
#  'New',
#  'York',
#  'to',
#  'experience',
#  'all',
#  'kinds',
#  'of',
#  'building',
#  'abuse',
#  'and',
#  'by',
#  'my',
#  'early',
#  'I',
#  'had',
#  'made',
#  'it',
#  'in',
#  'San',
#  'Francisco',
#  'as',
#  'an',
#  'executive',
#  'chef',
#  'which',
#  'meant',
#  'hour',
#  'workweeks',
#  'while',
#  'barely',
#  'scraping',
#  'by',
#  'pard',
#  'I',
#  'eventually',
#  'struck',
#  'out',
#  'on',
#  'my',
#  'own',
#  'deciding',
#  'to',
#  'play',
#  'it',
#  'safe',
#  'by',
#  'opening',
#  'a',
#  'restaurant',
#  'with',
#  'a',
#  'normal',
#  'business',
#  'model',
#  'And',
#  'as',
#  'is',
#  'usually',
#  'the',
#  'case',
#  'ul',
#  'normal',
#  'sucked',
#  'ulnone',
#  'Our',
#  'seats',
#  'were',
#  'full',
#  'every',
#  'night',
#  'employing',
#  'great',
#  'folks',
#  'and',
#  'serving',
#  'great',
#  'food',
#  'and',
#  'cocktails',
#  'and',
#  'sweating',
#  'our',
#  'rent',
#  'and',
#  'roughly',
#  'payroll',
#  'each',
#  'month',
#  'Structurally',
#  'our',
#  'mission',
#  'to',
#  'price',
#  'affordably',
#  'had',
#  'landed',
#  'us',
#  'in',
#  'the',
#  'death',
#  'zone',
#  'full',
#  'service',
#  'yet',
#  'unable',
#  'to',
#  'charge',
#  'fine',
#  'dining',
#  'prices',
#  'The',
#  'anxiety',
#  'was',
#  'weapons',
#  'grade',
#  'The',
#  'standard',
#  'model',
#  'for',
#  'a',
#  'business',
#  'almost',
#  'all',
#  'of',
#  'us',
#  'engage',
#  'with',
#  'regularly',
#  'ul',
#  'the',
#  'one',
#  'we',
#  'frequently',
#  'post',
#  'our',
#  'own',
#  'reviews',
#  'about',
#  'ulnone',
#  'has',
#  'barely',
#  'worked',
#  'for',
#  'a',
#  'majority',
#  'of',
#  'the',
#  'ul',
#  'more',
#  'than',
#  'million',
#  'people',
#  'ulnone',
#  'it',
#  'employs',
#  'The',
#  'restaurant',
#  'industry',
#  'accounts',
#  'for',
#  'some',
#  'percent',
#  'of',
#  'the',
#  'G',
#  'D',
#  'P',
#  'in',
#  'the',
#  'United',
#  'States',
#  'but',
#  'has',
#  'been',
#  'stuck',
#  'in',
#  'a',
#  'deeply',
#  'flawed',
#  'business',
#  'model',
#  'with',
#  'ul',
#  'sadly',
#  'outdated',
#  'ulnone',
#  'practices',
#  'The',
#  'pandemic',
#  'only',
#  'brought',
#  'this',
#  'reality',
#  'to',
#  'the',
#  'center',
#  'of',
#  'the',
#  'plate',
#  'and',
#  'made',
#  'it',
#  'something',
#  'we',
#  'couldn',
#  'push',
#  'aside',
#  'anymore',
#  'pard',
#  'Yet',
#  'I',
#  'find',
#  'deep',
#  'meaning',
#  'and',
#  'purpose',
#  'in',
#  'the',
#  'work',
#  'in',
#  'a',
#  'way',
#  'I',
#  'can',
#  'quite',
#  'put',
#  'my',
#  'finger',
#  'on',
#  'something',
#  'to',
#  'do',
#  'with',
#  'providing',
#  'for',
#  'other',
#  'human',
#  'beings',
#  'Then',
#  'it',
#  'was',
#  'March',
#  'I',
#  'was',
#  'sitting',
#  'at',
#  'the',
#  'redwood',
#  'table',
#  'I',
#  'recently',
#  'finished',
#  'staining',
#  'for',
#  'my',
#  'barely',
#  'year',
#  'old',
#  'restaurant',
#  'digesting',
#  'the',
#  'news',
#  'that',
#  'the',
#  'night',
#  'party',
#  'of',
#  'had',
#  'just',
#  'canceled',
#  'Something',
#  'called',
#  'Covid',
#  'was',
#  'causing',
#  'our',
#  'bookings',
#  'to',
#  'disappear',
#  'It',
#  'was',
#  'also',
#  'emptying',
#  'grocery',
#  'shelves',
#  'a',
#  'friend',
#  'asked',
#  'to',
#  'buy',
#  'three',
#  'flats',
#  'of',
#  'eggs',
#  'Right',
#  'next',
#  'to',
#  'me',
#  'sat',
#  'a',
#  'stack',
#  'of',
#  'invoices',
#  'pard',
#  'My',
#  'egg',
#  'friend',
#  'also',
#  'desperately',
#  'needed',
#  'paper',
#  'towels',
#  'since',
#  'evidently',
#  'grocery',
#  'stores',
#  'were',
#  'out',
#  'of',
#  'those',
#  'too',
#  'I',
#  'took',
#  'his',
#  'order',
#  'took',
#  'this',
#  'as',
#  'a',
#  'sign',
#  'and',
#  'flipped',
#  'our',
#  'space',
#  'ul',
#  'into',
#  'a',
#  'general',
#  'store',
#  'ulnone',
#  'It',
#  'took',
#  'off',
#  'we',
#  'even',
#  'hired',
#  'people',
#  'and',
#  'that',
#  'stack',
#  'of',
#  'bills',
#  'was',
#  'soon',
#  'paid',
#  'which',
#  'felt',
#  'like',
#  'a',
#  'triumph',
#  'But',
#  'after',
#  'five',
#  'chaotic',
#  'months',
#  'of',
#  'repackaging',
#  'bulk',
#  'food',
#  'the',
#  'supply',
#  'chain',
#  'adjusted',
#  'shelves',
#  'at',
#  'traditional',
#  'grocers',
#  'refilled',
#  'and',
#  'the',
#  'floor',
#  'fell',
#  'out',
#  'from',
#  'underneath',
#  'us',
#  'again',
#  'only',
#  'more',
#  'so',
#  'On',
#  'Aug',
#  'almost',
#  'the',
#  'same',
#  'day',
#  'Congress',
#  'decided',
#  'it',
#  'would',
#  'go',
#  'on',
#  'recess',
#  'without',
#  'any',
#  'agreement',
#  'for',
#  'additional',
#  'small',
#  'business',
#  'aid',
#  'I',
#  'made',
#  'the',
#  'gut',
#  'wrenching',
#  'decision',
#  'to',
#  'close',
#  'adding',
#  'me',
#  'and',
#  'my',
#  'staff',
#  'to',
#  'the',
#  'country',
#  'devastating',
#  'unemployment',
#  'statistics',
#  'pard',
#  'qc',
#  'pard',
#  'I',
#  'needed',
#  'to',
#  'find',
#  'some',
#  'work',
#  'or',
#  'to',
#  'create',
#  'some',
#  'and',
#  'I',
#  'remembered',
#  'a',
#  'crazy',
#  'idea',
#  'I',
#  'had',
#  'years',
#  'ago',
#  'while',
#  'driving',
#  'back',
#  'home',
#  'to',
#  'Iowa',
#  'My',
#  'mind',
#  'was',
#  'deep',
#  'in',
#  'so',
#  'frustrated',
#  'with',
#  'the',
#  'miserable',
#  'economics',
#  'of',
#  'my',
#  'chosen',
#  'profession',
#  'territory',
#  'as',
#  'I',
#  'passed',
#  'a',
#  'used',
#  'R',
#  'V',
#  'lot',
#  'I',
#  'chuckled',
#  'and',
#  'thought',
#  'you',
#  'should',
#  'just',
#  'open',
#  'a',
#  'tiny',
#  'private',
#  'dining',
#  'room',
#  'I',
#  'chuckled',
#  'again',
#  'nervously',
#  'as',
#  'I',
#  'recalled',
#  'it',
#  'Then',
#  'I',
#  'did',
#  'some',
#  'back',
#  'of',
#  'the',
#  'envelope',
#  'calculations',
#  'and',
#  'scraped',
#  'together',
#  'to',
#  'buy',
#  'a',
#  'Volkswagen',
#  'camper',
#  'I',
#  'found',
#  'on',
#  'Craigslist',
#  'I',
#  'renamed',
#  'the',
#  'van',
#  'SuperStella',
#  'and',
#  'rebuilt',
#  'her',
#  'with',
#  'a',
#  'surprisingly',
#  'luxurious',
#  'yes',
#  'really',
#  'dining',
#  'room',
#  'for',
#  'four',
#  'For',
#  'months',
#  'starting',
#  'in',
#  'November',
#  'ul',
#  'SuperStella',
#  'ulnone',
#  'served',
#  'two',
#  'Covid',
#  'safe',
#  'seatings',
#  'a',
#  'night',
#  'in',
#  'a',
#  'private',
#  'lot',
#  'that',
#  'had',
#  'a',
#  'commanding',
#  'view',
#  'of',
#  'the',
#  'Bay',
#  'Bridge',
#  'and',
#  'its',
#  'twinkling',
#  'lights',
#  'For',
#  'a',
#  'check',
#  'that',
#  'ranged',
#  'from',
#  'to',
#  'a',
#  'person',
#  'diners',
#  'enjoyed',
#  'a',
#  'glamping',
#  'themed',
#  'menu',
#  'of',
#  'things',
#  'like',
#  'whole',
#  'grilled',
#  'trout',
#  'with',
#  'nasturtium',
#  'butter',
#  'poured',
#  'from',
#  'a',
#  'thermos',
#  'and',
#  'a',
#  'fat',
#  'slice',
#  'of',
#  'grilled',
#  'milk',
#  'bread',
#  'with',
#  'salted',
#  'maple',
#  'butter',
#  'shaved',
#  'over',
#  'it',
#  'for',
#  'dessert',
#  'I',
#  'was',
#  'the',
#  'waiter',
#  'sommelier',
#  'and',
#  'cook',
#  'Not',
#  'only',
#  'did',
#  'I',
#  'get',
#  'tons',
#  'of',
#  'vitamin',
#  'D',
#  'for',
#  'once',
#  'and',
#  'bring',
#  'joy',
#  'to',
#  'some',
#  'lockdown',
#  'fatigued',
#  'diners',
#  'but',
#  'thanks',
#  'to',
#  'the',
#  'fact',
#  'that',
#  'I',
#  'had',
#  'low',
#  'to',
#  'no',
#  'overhead',
#  'I',
#  'was',
#  'also',
#  'making',
#  'a',
#  'comfortable',
#  'living',
#  'for',
#  'the',
#  'first',
#  'time',
#  'in',
#  'my',
#  'career',
#  'Was',
#  'SuperStella',
#  'a',
#  'restaurant',
#  'Technically',
#  'no',
#  'I',
#  'navigated',
#  'some',
#  'regulatory',
#  'gray',
#  'area',
#  'by',
#  'designating',
#  'it',
#  'as',
#  'catering',
#  'and',
#  'the',
#  'private',
#  'lot',
#  'as',
#  'a',
#  'venue',
#  'It',
#  'would',
#  'be',
#  'only',
#  'temporary',
#  'since',
#  'operating',
#  'longer',
#  'would',
#  'have',
#  'been',
#  'a',
#  'case',
#  'study',
#  'in',
#  'navigating',
#  'bureaucracy',
#  'No',
#  'thanks',
#  'But',
#  'I',
#  'was',
#  'emboldened',
#  'to',
#  'believe',
#  'that',
#  'whatever',
#  'I',
#  'did',
#  'next',
#  'could',
#  'and',
#  'would',
#  'make',
#  'money',
#  'All',
#  'I',
#  'had',
#  'to',
#  'do',
#  'was',
#  'throw',
#  'out',
#  'the',
#  'definition',
#  'of',
#  'how',
#  'a',
#  'restaurant',
#  'normally',
#  'works',
#  'and',
#  'start',
#  'over',
#  'from',
#  'scratch',
#  'pard',
#  'Fast',
#  'forward',
#  'to',
#  'today',
#  'Most',
#  'days',
#  'you',
#  'find',
#  'me',
#  'at',
#  'my',
#  'ul',
#  'new',
#  'pasta',
#  'shop',
#  'ulnone',
#  'in',
#  'a',
#  'residential',
#  'neighborhood',
#  'on',
#  'the',
#  'west',
#  'side',
#  'of',
#  'San',
#  'Francisco',
#  'where',
#  'we',
#  'rethought',
#  'pretty',
#  'much',
#  'everything',
#  'in',
#  'order',
#  'to',
#  'create',
#  'a',
#  'sustainable',
#  'business',
#  'model',
#  'pard',
#  'pard',
#  'Standard',
#  'restaurant',
#  'logic',
#  'dictates',
#  'that',
#  'your',
#  'dining',
#  'room',
#  'be',
#  'as',
#  'big',
#  'as',
#  'possible',
#  'but',
#  'we',
#  'cut',
#  'ours',
#  'in',
#  'half',
#  'to',
#  'just',
#  'seats',
#  'so',
#  'the',
#  'business',
#  'has',
#  'an',
#  'additional',
#  'leg',
#  'to',
#  'stand',
#  'on',
#  'a',
#  'retail',
#  'shop',
#  'that',
#  'is',
#  'open',
#  'all',
#  'day',
#  'selling',
#  'freshly',
#  'made',
#  'pastas',
#  'sauces',
#  'and',
#  'high',
#  'end',
#  'pantry',
#  'items',
#  'all',
#  'of',
#  'it',
#  'prepared',
#  'and',
#  'curated',
#  'for',
#  'people',
#  'to',
#  'make',
#  'easy',
#  ...]

# %%
# what about any digits from 2-4 digits in length?

re.findall("\d{2,4}", myString)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/3898624025.py:3: SyntaxWarning: invalid escape sequence '\d'
#   re.findall("\d{2,4}", myString)
# ['40',
#  '92',
#  '720',
#  '15',
#  '93',
#  '94',
#  '30',
#  '85',
#  '80',
#  '32',
#  '720',
#  '300',
#  '40',
#  '80',
#  '97',
#  '11',
#  '000',
#  '90',
#  '000',
#  '12',
#  '92',
#  '34',
#  '720',
#  '300',
#  '40',
#  '92',
#  '2020',
#  '92',
#  '92',
#  '18',
#  '19',
#  '720',
#  '11',
#  '2020',
#  '92',
#  '32',
#  '720',
#  '720',
#  '300',
#  '40',
#  '93',
#  '92',
#  '94',
#  '93',
#  '94',
#  '18',
#  '000',
#  '1989',
#  '11',
#  '2020',
#  '88',
#  '165',
#  '92',
#  '720',
#  '92',
#  '92',
#  '720',
#  '32',
#  '720',
#  '300',
#  '40',
#  '35',
#  '92',
#  '92',
#  '15',
#  '92',
#  '20',
#  '720',
#  '92',
#  '85',
#  '92',
#  '15',
#  '92',
#  '32',
#  '720',
#  '720',
#  '300',
#  '40',
#  '92',
#  '92',
#  '92',
#  '97',
#  '97',
#  '720',
#  '92',
#  '97']

# %%
# you can even use this syntax to set a lower limit but no upper limit
re.findall("\d{3}", myString)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/3290362973.py:2: SyntaxWarning: invalid escape sequence '\d'
#   re.findall("\d{3}", myString)
# ['720',
#  '720',
#  '300',
#  '000',
#  '000',
#  '720',
#  '300',
#  '202',
#  '720',
#  '202',
#  '720',
#  '720',
#  '300',
#  '000',
#  '198',
#  '202',
#  '165',
#  '720',
#  '720',
#  '720',
#  '300',
#  '720',
#  '720',
#  '720',
#  '300',
#  '720']

# %%
# find the word restaurant and the word preceding it and the word following it

re.findall("\w+ restaurant \w+", myString)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/1279963110.py:3: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("\w+ restaurant \w+", myString)
# ['the restaurant business',
#  'a restaurant does',
#  'a restaurant with',
#  'The restaurant industry',
#  'a restaurant normally',
#  'Standard restaurant logic',
#  'Our restaurant is']

# %% [markdown]
# ### Metacharacters
# Metacharacters are characters with a special meaning:

# %%
# open the sorcerers-stone.txt file

import re

with open("data/sorcerers-stone.txt", "r", encoding = "utf8") as f:
    story = f.read()

story
# Out:
# 'THE BOY WHO LIVED\n\nMr. and Mrs. Dursley, of number four, Privet Drive,\nwere proud to say that they were perfectly normal,\nthank you very much. They were the last people you’d\nexpect to be involved in anything strange or\nmysterious, because they just didn’t hold with such\nnonsense.\n\nMr. Dursley was the director of a firm called\nGrunnings, which made drills. He was a big, beefy\nman with hardly any neck, although he did have a\nvery large mustache. Mrs. Dursley was thin and\nblonde and had nearly twice the usual amount of\nneck, which came in very useful as she spent so\nmuch of her time craning over garden fences, spying\non the neighbors. The Dursley s had a small son\ncalled Dudley and in their opinion there was no finer\nboy anywhere.\n\nThe Dursleys had everything they wanted, but they\nalso had a secret, and their greatest fear was that\nsomebody would discover it. They didn’t think they\ncould bear it if anyone found out about the Potters.\nMrs. Potter was Mrs. Dursley’s sister, but they hadn’t\n\n\n\n\n\nmet for several years; in fact, Mrs. Dursley pretended\nshe didn’t have a sister, because her sister and her\ngood-for-nothing husband were as unDursleyish as it\nwas possible to be. The Dursleys shuddered to think\nwhat the neighbors would say if the Potters arrived in\nthe street. The Dursleys knew that the Potters had a\nsmall son, too, but they had never even seen him.\n\nThis boy was another good reason for keeping the\nPotters away; they didn’t want Dudley mixing with a\nchild like that.\n\nWhen Mr. and Mrs. Dursley woke up on the dull, gray\nTuesday our story starts, there was nothing about the\ncloudy sky outside to suggest that strange and\nmysterious things would soon be happening all over\nthe country. Mr. Dursley hummed as he picked out\nhis most boring tie for work, and Mrs. Dursley\ngossiped away happily as she wrestled a screaming\nDudley into his high chair.\n\nNone of them noticed a large, tawny owl flutter past\nthe window.\n\nAt half past eight, Mr. Dursley picked up his\nbriefcase, pecked Mrs. Dursley on the cheek, and\ntried to kiss Dudley good-bye but missed, because\nDudley was now having a tantrum and throwing his\ncereal at the walls. “Little tyke,” chortled Mr. Dursley\nas he left the house. He got into his car and backed\nout of number four’s drive.\n\nIt was on the corner of the street that he noticed the\nfirst sign of something peculiar — a cat reading a\nmap. For a second, Mr. Dursley didn’t realize what he\nhad seen — then he jerked his head around to look\nagain. There was a tabby cat standing on the corner\nof Privet Drive, but there wasn’t a map in sight. What\ncould he have been thinking of? It must have been a\ntrick of the light. Mr. Dursley blinked and stared at\n\n\n\n\n\nthe cat. It stared back. As Mr. Dursley drove around\nthe corner and up the road, he watched the cat in his\nmirror. It was now reading the sign that said Privet\nDrive — no, looking at the sign; cats couldn’t read\nmaps or signs. Mr. Dursley gave himself a little shake\nand put the cat out of his mind. As he drove toward\ntown he thought of nothing except a large order of\ndrills he was hoping to get that day.\n\nBut on the edge of town, drills were driven out of his\nmind by something else. As he sat in the usual\nmorning traffic jam, he couldn’t help noticing that\nthere seemed to be a lot of strangely dressed people\nabout. People in cloaks. Mr. Dursley couldn’t bear\npeople who dressed in funny clothes — the getups\nyou saw on young people! He supposed this was some\nstupid new fashion. He drummed his fingers on the\nsteering wheel and his eyes fell on a huddle of these\nweirdos standing quite close by. They were whispering\nexcitedly together. Mr. Dursley was enraged to see\nthat a couple of them weren’t young at all; why, that\nman had to be older than he was, and wearing an\nemerald-green cloak! The nerve of him! But then it\nstruck Mr. Dursley that this was probably some silly\nstunt — these pe ...

# %%
# clean your code and stip the new lines and the spaces

story = story.replace("\n", " ")

story
# Out:
# 'THE BOY WHO LIVED  Mr. and Mrs. Dursley, of number four, Privet Drive, were proud to say that they were perfectly normal, thank you very much. They were the last people you’d expect to be involved in anything strange or mysterious, because they just didn’t hold with such nonsense.  Mr. Dursley was the director of a firm called Grunnings, which made drills. He was a big, beefy man with hardly any neck, although he did have a very large mustache. Mrs. Dursley was thin and blonde and had nearly twice the usual amount of neck, which came in very useful as she spent so much of her time craning over garden fences, spying on the neighbors. The Dursley s had a small son called Dudley and in their opinion there was no finer boy anywhere.  The Dursleys had everything they wanted, but they also had a secret, and their greatest fear was that somebody would discover it. They didn’t think they could bear it if anyone found out about the Potters. Mrs. Potter was Mrs. Dursley’s sister, but they hadn’t      met for several years; in fact, Mrs. Dursley pretended she didn’t have a sister, because her sister and her good-for-nothing husband were as unDursleyish as it was possible to be. The Dursleys shuddered to think what the neighbors would say if the Potters arrived in the street. The Dursleys knew that the Potters had a small son, too, but they had never even seen him.  This boy was another good reason for keeping the Potters away; they didn’t want Dudley mixing with a child like that.  When Mr. and Mrs. Dursley woke up on the dull, gray Tuesday our story starts, there was nothing about the cloudy sky outside to suggest that strange and mysterious things would soon be happening all over the country. Mr. Dursley hummed as he picked out his most boring tie for work, and Mrs. Dursley gossiped away happily as she wrestled a screaming Dudley into his high chair.  None of them noticed a large, tawny owl flutter past the window.  At half past eight, Mr. Dursley picked up his briefcase, pecked Mrs. Dursley on the cheek, and tried to kiss Dudley good-bye but missed, because Dudley was now having a tantrum and throwing his cereal at the walls. “Little tyke,” chortled Mr. Dursley as he left the house. He got into his car and backed out of number four’s drive.  It was on the corner of the street that he noticed the first sign of something peculiar — a cat reading a map. For a second, Mr. Dursley didn’t realize what he had seen — then he jerked his head around to look again. There was a tabby cat standing on the corner of Privet Drive, but there wasn’t a map in sight. What could he have been thinking of? It must have been a trick of the light. Mr. Dursley blinked and stared at      the cat. It stared back. As Mr. Dursley drove around the corner and up the road, he watched the cat in his mirror. It was now reading the sign that said Privet Drive — no, looking at the sign; cats couldn’t read maps or signs. Mr. Dursley gave himself a little shake and put the cat out of his mind. As he drove toward town he thought of nothing except a large order of drills he was hoping to get that day.  But on the edge of town, drills were driven out of his mind by something else. As he sat in the usual morning traffic jam, he couldn’t help noticing that there seemed to be a lot of strangely dressed people about. People in cloaks. Mr. Dursley couldn’t bear people who dressed in funny clothes — the getups you saw on young people! He supposed this was some stupid new fashion. He drummed his fingers on the steering wheel and his eyes fell on a huddle of these weirdos standing quite close by. They were whispering excitedly together. Mr. Dursley was enraged to see that a couple of them weren’t young at all; why, that man had to be older than he was, and wearing an emerald-green cloak! The nerve of him! But then it struck Mr. Dursley that this was probably some silly stunt — these people were obviously collecting for something ... yes, that would be it. The traffic moved on and a  ...

# %%
# find all the times "witch" is said

re.findall("witch", story)
# Out:
# ['witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch',
#  'witch']

# %%
# find what words come after "Harry"

re.findall("Harry \w+", story)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/1828929905.py:3: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("Harry \w+", story)
# ['Harry Potter',
#  'Harry survive',
#  'Harry to',
#  'Harry Potter',
#  'Harry Potter',
#  'Harry underneath',
#  'Harry in',
#  'Harry and',
#  'Harry off',
#  'Harry gently',
#  'Harry Potter',
#  'Harry Potter',
#  'Harry Potter',
#  'Harry woke',
#  'Harry heard',
#  'Harry groaned',
#  'Harry got',
#  'Harry was',
#  'Harry didn',
#  'Harry had',
#  'Harry had',
#  'Harry liked',
#  'Harry was',
#  'Harry needed',
#  'Harry must',
#  'Harry was',
#  'Harry often',
#  'Harry put',
#  'Harry and',
#  'Harry was',
#  'Harry hated',
#  'Harry as',
#  'Harry knew',
#  'Harry like',
#  'Harry put',
#  'Harry a',
#  'Harry aside',
#  'Harry and',
#  'Harry coming',
#  'Harry wasn',
#  'Harry had',
#  'Harry supposed',
#  'Harry were',
#  'Harry what',
#  'Harry thought',
#  'Harry had',
#  'Harry was',
#  'Harry felt',
#  'Harry moved',
#  'Harry stared',
#  'Harry a',
#  'Harry murmured',
#  'Harry asked',
#  'Harry peered',
#  'Harry read',
#  'Harry made',
#  'Harry in',
#  'Harry fell',
#  'Harry sat',
#  'Harry could',
#  'Harry had',
#  'Harry at',
#  'Harry was',
#  'Harry lay',
#  'Harry had',
#  'Harry furiously',
#  'Harry tried',
#  'Harry had',
#  'Harry Potter',
#  'Harry his',
#  'Harry was',
#  'Harry Hunting',
#  'Harry spent',
#  'Harry at',
#  'Harry watch',
#  'Harry didn',
#  'Harry went',
#  'Harry looked',
#  'Harry seriously',
#  'Harry get',
#  'Harry dodged',
#  'Harry picked',
#  'Harry saw',
#  'Harry went',
#  'Harry was',
#  'Harry and',
#  'Harry furiously',
#  'Harry didn',
#  'Harry and',
#  'Harry and',
#  'Harry could',
#  'Harry in',
#  'Harry angrily',
#  'Harry one',
#  'Harry sighed',
#  'Harry was',
#  'Harry right',
#  'Harry had',
#  'Harry walked',
#  'Harry turned',
#  'Harry leapt',
#  'Harry realized',
#  'Harry didn',
#  'Harry for',
#  'Harry shuffled',
#  'Harry could',
#  'Harry found',
#  'Harry in',
#  'Harry leapt',
#  'Harry around',
#  'Harry shared',
#  'Harry stayed',
#  'Harry made',
#  'Harry of',
#  'Harry privately',
#  'Harry was',
#  'Harry couldn',
#  'Harry he',
#  'Harry heard',
#  'Harry sat',
#  'Harry looked',
#  'Harry opened',
#  'Harry written',
#  'Harry looked',
#  'Harry felt',
#  'Harry said',
#  'Harry thought',
#  'Harry with',
#  'Harry eagerly',
#  'Harry stretched',
#  'Harry could',
#  'Harry his',
#  'Harry realized',
#  'Harry had',
#  'Harry Potter',
#  'Harry asked',
#  'Harry suggested',
#  'Harry jumped',
#  'Harry with',
#  'Harry looked',
#  'Harry looked',
#  'Harry Potter',
#  'Harry saw',
#  'Harry under',
#  'Harry woke',
#  'Harry thought',
#  'Harry mumbled',
#  'Harry scrambled',
#  'Harry tried',
#  'Harry loudly',
#  'Harry pulled',
#  'Harry counted',
#  'Harry could',
#  'Harry was',
#  'Harry dropped',
#  'Harry followed',
#  'Harry asked',
#  'Harry still',
#  'Harry another',
#  'Harry asked',
#  'Harry sat',
#  'Harry had',
#  'Harry asked',
#  'Harry couldn',
#  'Harry so',
#  'Harry took',
#  'Harry unfolded',
#  'Harry wondered',
#  'Harry had',
#  'Harry had',
#  'Harry hadn',
#  'Harry couldn',
#  'Harry wouldn',
#  'Harry had',
#  'Harry Potter',
#  'Harry and',
#  'Harry didn',
#  'Harry found',
#  'Harry shook',
#  'Harry to',
#  'Harry looked',
#  'Harry wished',
#  'Harry heard',
#  'Harry had',
#  'Harry noticed',
#  'Harry made',
#  'Harry Potter',
#  'Harry watched',
#  'Harry followed',
#  'Harry asked',
#  'Harry tried',
#  'Harry called',
#  'Harry gasped',
#  'Harry cost',
#  'Harry pile',
#  'Harry leaned',
#  'Harry asked',
#  'Harry was',
#  'Harry longed',
#  'Harry didn',
#  'Harry entered',
#  'Harry started',
#  'Harry on',
#  'Harry was',
#  'Harry said',
#  'Harry and',
#  'Harry coldly',
#  'Harry shortly',
#  'Harry could',
#  'Harry was',
#  'Harry lied',
#  'Harry cheered',
#  'Harry gloomily',
#  'Harry away',
#  'Harry buy',
#  'Harry himself',
#  'Harry felt',
#  'Harry now',
#  'Harry had',
#  'Harry felt',
#  'Harry jumped',
#  'Harry awkwardly',
#  'Harry Potter',
#  'Harry wished',
#  'Harry were',
#  'Harry could',
#  'Harry noticed',
#  'Harry from',
#  'Harry suddenly',
#  'Harry took',
#  'Harry tried',
#  'Harry tried',
#  'Harry took',
#  'Harry with',
#  'Harry swallowed',
#  'Harry shivered',
#  'Harry and',
#  'Harry didn',
#  'Harry only',
#  'Harry a',
#  'Harry kept',
#  'Harry wasn',
#  'Harry on',
#  'Harry wanted',
#  'Harry he',
#  'Harry in',
#  'Harry in',
#  'Harry kept',
#  'Harry ticked',
#  'Harry supposed',
#  'Harry didn',
#  'Harry asked',
#  'Harry woke',
#  'Harry thought',
#  'Harry turned',
#  'Harry couldn',
#  'Harry was',
#  'Harry asked',
#  'Harry was',
#  'Harry swung',
#  'Harry pushed',
#  'Harry watched',
#  'Harry said',
#  'Harry nodded',
#  'Harry walked',
#  'Harry looked',
#  'Harry pushed',
#  'Harry pressed',
#  'Harry panted',
#  'Harry Potter',
#  'Harry felt',
#  'Harry sat',
#  'Harry noticed',
#  'Harry leaned',
#  'Harry Potted',
#  'Harry heard',
#  'Harry saw',
#  'Harry watched',
#  'Harry felt',
#  'Harry shook',
#  'Harry and',
#  'Harry saw',
#  'Harry and',
#  'Harry Potter',
#  'Harry nodded',
#  'Harry pulled',
#  'Harry for',
#  'Harry didn',
#  'Harry went',
#  'Harry had',
#  'Harry brought',
#  'Harry asked',
#  'Harry unwrapped',
#  'Harry turned',
#  'Harry turned',
#  'Harry stared',
#  'Harry couldn',
#  'Harry got',
#  'Harry had',
#  'Harry looked',
#  'Harry Potter',
#  'Harry was',
#  'Harry stared',
#  'Harry turned',
#  'Harry confessed',
#  'Harry through',
#  'Harry recognized',
#  'Harry with',
#  'Harry Potter',
#  'Harry was',
#  'Harry didn',
#  'Harry and',
#  'Harry explained',
#  'Harry peered',
#  'Harry shivered',
#  'Harry heard',
#  'Harry thought',
#  'Harry and',
#  'Harry could',
#  'Harry nervously',
#  'Harry swallowed',
#  'Harry tried',
#  'Harry got',
#  'Harry had',
#  'Harry looked',
#  'Harry quickly',
#  'Harry thought',
#  'Harry smiled',
#  'Harry didn',
#  'Harry saw',
#  'Harry could',
#  'Harry noticed',
#  'Harry in',
#  'Harry stepped',
#  'Harry Potter',
#  'Harry saw',
#  'Harry gripped',
#  'Harry heard',
#  'Harry sat',
#  'Harry the',
#  'Harry grinned',
#  'Harry recognized',
#  'Harry spotted',
#  'Harry at',
#  'Harry crossed',
#  'Harry clapped',
#  'Harry as',
#  'Harry looked',
#  'Harry didn',
#  'Harry really',
#  'Harry piled',
#  'Harry cut',
#  'Harry looked',
#  'Harry was',
#  'Harry helped',
#  'Harry clapped',
#  'Harry had',
#  'Harry at',
#  'Harry watched',
#  'Harry laughed',
#  'Harry noticed',
#  'Harry was',
#  'Harry through',
#  'Harry was',
#  'Harry had',
#  'Harry told',
#  'Harry woke',
#  'Harry from',
#  'Harry wished',
#  'Harry was',
#  'Harry and',
#  'Harry quickly',
#  'Harry had',
#  'Harry was',
#  'Harry and',
#  'Harry asked',
#  'Harry had',
#  'Harry anything',
#  'Harry tore',
#  'Harry borrowed',
#  'Harry had',
#  'Harry had',
#  'Harry Potter',
#  'Harry and',
#  'Harry glanced',
#  'Harry didn',
#  'Harry forced',
#  'Harry quietly',
#  'Harry caught',
#  'Harry and',
#  'Harry opened',
#  'Harry knocked',
#  'Harry told',
#  'Harry and',
#  'Harry and',
#  'Harry told',
#  'Harry not',
#  'Harry couldn',
#  'Harry wondered',
#  'Harry picked',
#  'Harry remembered',
#  'Harry read',
#  'Harry and',
#  'Harry thought',
#  'Harry had',
#  'Harry darkly',
#  'Harry had',
#  'Harry felt',
#  'Harry hadn',
#  'Harry and',
#  'Harry had',
#  'Harry glanced',
#  'Harry and',
#  'Harry saw',
#  'Harry heard',
#  'Harry quietly',
#  'Harry yelled',
#  'Harry grabbed',
#  'Harry ignored',
#  'Harry called',
#  'Harry knew',
#  'Harry made',
#  'Harry called',
#  'Harry saw',
#  'Harry caught',
#  'Harry trotting',
#  'Harry nodded',
#  'Harry and',
#  'Harry had',
#  'Harry coolly',
#  'Harry looked',
#  'Harry thought',
#  'Harry felt',
#  'Harry couldn',
#  'Harry sharply',
#  'Harry hissed',
#  'Harry expected',
#  'Harry took',
#  'Harry had',
#  'Harry waved',
#  'Harry mouthed',
#  'Harry yelled',
#  'Harry in',
#  'Harry panted',
#  'Harry thought',
#  'Harry whispered',
#  'Harry turned',
#  'Harry knew',
#  'Harry groped',
#  'Harry slammed',
#  'Harry suggested',
#  'Harry something',
#  'Harry had',
#  'Harry and',
#  'Harry and',
#  'Harry filled',
#  'Harry and',
#  'Harry was',
#  'Harry ripped',
#  'Harry had',
#  'Harry and',
#  'Harry with',
#  'Harry and',
#  'Harry chortled',
#  'Harry had',
#  'Harry left',
#  'Harry of',
#  'Harry mounted',
#  'Harry landed',
#  'Harry repeated',
#  'Harry recited',
#  'Harry quickly',
#  'Harry a',
#  'Harry two',
#  'Harry noticed',
#  'Harry swung',
#  'Harry reeled',
#  'Harry asked',
#  'Harry shook',
#  'Harry were',
#  'Harry to',
#  'Harry didn',
#  'Harry could',
#  'Harry and',
#  'Harry had',
#  'Harry heard',
#  'Harry as',
#  'Harry as',
#  'Harry caught',
#  'Harry and',
#  'Harry was',
#  'Harry asked',
#  'Harry suddenly',
#  'Harry behind',
#  'Harry whispered',
#  'Harry said',
#  'Harry sniffed',
#  'Harry muttered',
#  'Harry managed',
#  'Harry gasped',
#  'Harry pulled',
#  'Harry said',
#  'Harry time',
#  'Harry yelled',
#  'Harry then',
#  'Harry hanging',
#  'Harry clinging',
#  'Harry got',
#  'Harry had',
#  'Harry looked',
#  'Harry a',
#  'Harry looked',
#  'Harry stuck',
#  'Harry and',
#  'Harry was',
#  'Harry and',
#  'Harry reminded',
#  'Harry would',
#  'Harry play',
#  'Harry should',
#  'Harry didn',
#  'Harry now',
#  'Harry learned',
#  'Harry and',
#  'Harry noticed',
#  'Harry showed',
#  'Harry muttered',
#  'Harry and',
#  'Harry felt',
#  'Harry had',
#  'Harry tried',
#  'Harry gulped',
#  'Harry left',
#  'Harry joined',
#  'Harry told',
#  'Harry went',
#  'Harry couldn',
#  'Harry had',
#  'Harry felt',
#  'Harry and',
#  'Harry followed',
#  'Harry noticed',
#  'Harry thought',
#  'Harry clambered',
#  'Harry hasn',
#  'Harry was',
#  'Harry had',
#  'Harry dodged',
#  'Harry saw',
#  'Harry was',
#  'Harry on',
#  'Harry holding',
#  'Harry outta',
#  'Harry dodged',
#  'Harry tried',
#  'Harry thinks',
#  'Harry all',
#  'Harry swung',
#  'Harry and',
#  'Harry safely',
#  'Harry was',
#  'Harry was',
#  'Harry hadn',
#  'Harry heard',
#  'Harry decided',
#  'Harry eagerly',
#  'Harry as',
#  'Harry as',
#  'Harry had',
#  'Harry about',
#  'Harry wasn',
#  'Harry had',
#  'Harry told',
#  'Harry added',
#  'Harry wandered',
#  'Harry left',
#  'Harry waited',
#  'Harry were',
#  'Harry wizard',
#  'Harry played',
#  'Harry went',
#  'Harry scrambled',
#  'Harry picked',
#  'Harry blew',
#  'Harry had',
#  'Harry picked',
#  'Harry picked',
#  'Harry threw',
#  'Harry looked',
#  'Harry pulled',
#  'Harry stared',
#  'Harry stuffed',
#  'Harry got',
#  'Harry had',
#  'Harry pulled',
#  'Harry watched',
#  'Harry finally',
#  'Harry had',
#  'Harry and',
#  'Harry broke',
#  'Harry leaned',
#  'Harry felt',
#  'Harry wake',
#  'Harry said',
#  'Harry lit',
#  'Harry could',
#  'Harry couldn',
#  'Harry snapped',
#  'Harry slipped',
#  'Harry felt',
#  'Harry stood',
#  'Harry leaned',
#  'Harry moved',
#  'Harry looked',
#  'Harry thought',
#  'Harry was',
#  'Harry looked',
#  'Harry was',
#  'Harry and',
#  'Harry couldn',
#  'Harry feared',
#  'Harry hissed',
#  'Harry spotted',
#  'Harry dropped',
#  'Harry whispered',
#  'Harry stepped',
#  'Harry stood',
#  'Harry out',
#  'Harry only',
#  'Harry sank',
#  'Harry felt',
#  'Harry must',
#  'Harry was',
#  'Harry shook',
#  'Harry thought',
#  'Harry stood',
#  'Harry stared',
#  'Harry that',
#  'Harry not',
#  'Harry wished',
#  'Harry told',
#  'Harry being',
#  'Harry was',
#  'Harry had',
#  'Harry was',
#  'Harry found',
#  'Harry headed',
#  'Harry and',
#  'Harry sat',
#  'Harry told',
#  'Harry and',
#  'Harry felt',
#  'Harry said',
#  'Harry looked',
#  'Harry and',
#  'Harry and',
#  'Harry and',
#  'Harry and',
#  'Harry and',
#  'Harry remembered',
#  'Harry became',
#  'Harry didn',
#  'Harry didn',
#  'Harry knew',
#  'Harry hardly',
#  'Harry know',
#  'Harry aside',
#  'Harry could',
#  'Harry had',
#  'Harry streaked',
#  'Harry sped',
#  'Harry had',
#  'Harry jumped',
#  'Harry felt',
#  'Harry could',
#  'Harry left',
#  'Harry had',
#  'Harry jumped',
#  'Harry couldn',
#  'Harry strained',
#  'Harry leaned',
#  'Harry nearly',
#  'Harry could',
#  'Harry on',
#  'Harry breathlessly',
#  'Harry passed',
#  'Harry and',
#  'Harry and',
#  'Harry and',
#  'Harry knew',
#  'Harry anxiously',
#  'Harry muttered',
#  'Harry noticed',
#  'Harry looked',
#  'Harry and',
#  'Harry another',
#  'Harry whispered',
#  'Harry didn',
#  'Harry thought',
#  'Harry bolted',
#  'Harry urged',
#  'Harry loudly',
#  'Harry suddenly',
#  'Harry sitting',
#  'Harry and',
#  'Harry and',
#  'Harry and',
#  'Harry told',
#  'Harry and',
#  'Harry as',
#  'Harry and',
#  'Harry panted',
#  'Harry Potter',
#  'Harry advised',
#  'Harry and',
#  'Harry and',
#  'Harry thought',
#  'Harry shook',
#  'Harry caught',
#  'Harry knew',
#  'Harry gasped',
#  'Harry felt',
#  'Harry didn',
#  'Harry couldn',
#  'Harry Potter',
#  'Harry Potter',
#  'Harry was',
#  'Harry went',
#  'Harry miserably',
#  'Harry swore',
#  'Harry during',
#  'Harry was',
#  'Harry moved',
#  'Harry didn',
#  'Harry was',
#  'Harry had',
#  'Harry went',
#  'Harry told',
#  'Harry could',
#  'Harry flatly',
#  'Harry had',
#  'Harry had',
#  'Harry wondered',
#  'Harry could',
#  'Harry was',
#  'Harry saw',
#  'Harry asked',
#  'Harry could',
#  'Harry and',
#  'Harry suggested',
#  'Harry and',
#  'Harry Potter',
#  'Harry and',
#  'Harry kept',
#  'Harry set',
#  'Harry thought',
#  'Harry could',
#  'Harry had',
#  'Harry had',
#  'Harry to',
#  'Harry could',
#  'Harry had',
#  'Harry clutching',
#  'Harry didn',
#  'Harry to',
#  'Harry thought',
#  'Harry Potter',
#  'Harry stared',
#  'Harry croaked',
#  'Harry slid',
#  'Harry Potter',
#  'Harry shivering',
#  'Harry roughly',
#  'Harry began',
#  'Harry couldn',
#  'Harry wasn',
#  'Harry went',
#  'Harry pulled',
#  'Harry would',
#  'Harry did',
#  'Harry had',
#  'Harry couldn',
#  'Harry kept',
#  'Harry had',
#  'Harry couldn',
#  'Harry was',
#  'Harry nodded',
#  'Harry was',
#  'Harry suddenly',
#  'Harry cut',
#  'Harry sank',
#  'Harry asked',
#  'Harry began',
#  'Harry and',
#  'Harry swallowed',
#  'Harry frantically',
#  'Harry and',
#  'Harry began',
#  'Harry flushed',
#  'Harry turned',
#  'Harry told',
#  'Harry and',
#  'Harry had',
#  'Harry said',
#  'Harry shouted',
#  'Harry any',
#  'Harry and',
#  'Harry ran',
#  'Harry looked',
#  'Harry turned',
#  'Harry whispered',
#  'Harry shook',
#  'Harry had',
#  'Harry said',
#  'Harry turned',
#  'Harry pushed',
#  'Harry hardly',
#  'Harry as',
#  'Harry handed',
#  'Harry climbed',
#  'Harry let',
#  'Harry and',
#  'Harry gasped',
#  'Harry choked',
#  'Harry as',
#  'Harry doesn',
#  'Harry was',
#  'Harry listened',
#  'Harry said',
#  'Harry the',
#  'Harry was',
#  'Harry called',
#  'Harry streaked',
#  'Harry leaned',
#  'Harry ran',
#  'Harry asked',
#  'Harry whispered',
#  'Harry and',
#  'Harry quickly',
#  'Harry and',
#  'Harry and',
#  'Harry moved',
#  'Harry and',
#  'Harry whispered',
#  'Harry pushed',
#  'Harry whispered',
#  'Harry looked',
#  'Harry looked',
#  'Harry and',
#  'Harry anxiously',
#  'Harry took',
#  'Harry couldn',
#  'Harry realized',
#  'Harry could',
#  'Harry struggled',
#  'Harry gasped',
#  'Harry was',
#  'Harry fell',
#  'Harry got',
#  'Harry walked',
#  'Harry breathed',
#  'Harry felt',
#  'Harry screwed',
#  'Harry moved',
#  'Harry felt',
#  'Harry would',
#  'Harry had',
#  'Harry Potter',
#  'Harry tried',
#  'Harry shouted',
#  'Harry sprang',
#  'Harry felt',
#  'Harry clean',
#  'Harry to',
#  'Harry could',
#  'Harry knew',
#  'Harry jumped',
#  'Harry off',
#  'Harry stared',
#  'Harry swallowed',
#  'Harry blankly',
#  'Harry lay',
#  'Harry nodded',
#  'Harry knew',
#  'Harry time',
#  'Harry said',
#  'Harry tried',
#  'Harry pleaded',
#  'Harry was',
#  'Harry told',
#  'Harry told',
#  'Harry thoughtfully',
#  'Harry felt',
#  'Harry bellowed',
#  'Harry anxiously',
#  'Harry opened',
#  'Harry couldn',
#  'Harry made',
#  'Harry walked',
#  'Harry could',
#  'Harry strongly',
#  'Harry Potter',
#  'Harry just',
#  'Harry knew',
#  'Harry had',
#  'Harry Potter',
#  'Harry hung']

# %%
# find how many times magic appears (upper and lowercase)

re.findall('[mM]agic', story)
# Out:
# ['magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'Magic',
#  'Magic',
#  'Magic',
#  'magic',
#  'Magic',
#  'Magic',
#  'Magic',
#  'Magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'Magic',
#  'Magic',
#  'magic',
#  'magic',
#  'magic',
#  'Magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'magic',
#  'Magic',
#  'magic',
#  'magic',
#  'Magic',
#  'magic',
#  'magic',
#  'magic',
#  'Magic',
#  'Magic',
#  'Magic',
#  'Magic',
#  'Magic',
#  'magic',
#  'magic',
#  'magic',
#  'Magic',
#  'Magic',
#  'Magic',
#  'Magic',
#  'magic',
#  'magic',
#  'magic']

# %%
# find all the words that start with a vowel

re.findall("\\b[aeiouAEIOU]\w+", story)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/2249385880.py:3: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("\\b[aeiouAEIOU]\w+", story)
# ['and',
#  'of',
#  'expect',
#  'involved',
#  'in',
#  'anything',
#  'or',
#  'of',
#  'any',
#  'although',
#  'and',
#  'and',
#  'usual',
#  'amount',
#  'of',
#  'in',
#  'useful',
#  'as',
#  'of',
#  'over',
#  'on',
#  'and',
#  'in',
#  'opinion',
#  'anywhere',
#  'everything',
#  'also',
#  'and',
#  'it',
#  'it',
#  'if',
#  'anyone',
#  'out',
#  'about',
#  'in',
#  'and',
#  'as',
#  'unDursleyish',
#  'as',
#  'it',
#  'if',
#  'arrived',
#  'in',
#  'even',
#  'another',
#  'away',
#  'and',
#  'up',
#  'on',
#  'our',
#  'about',
#  'outside',
#  'and',
#  'all',
#  'over',
#  'as',
#  'out',
#  'and',
#  'away',
#  'as',
#  'into',
#  'of',
#  'owl',
#  'At',
#  'eight',
#  'up',
#  'on',
#  'and',
#  'and',
#  'at',
#  'as',
#  'into',
#  'and',
#  'out',
#  'of',
#  'It',
#  'on',
#  'of',
#  'of',
#  'around',
#  'again',
#  'on',
#  'of',
#  'in',
#  'of',
#  'It',
#  'of',
#  'and',
#  'at',
#  'It',
#  'As',
#  'around',
#  'and',
#  'up',
#  'in',
#  'It',
#  'at',
#  'or',
#  'and',
#  'out',
#  'of',
#  'As',
#  'of',
#  'except',
#  'order',
#  'of',
#  'on',
#  'edge',
#  'of',
#  'out',
#  'of',
#  'else',
#  'As',
#  'in',
#  'usual',
#  'of',
#  'about',
#  'in',
#  'in',
#  'on',
#  'on',
#  'and',
#  'eyes',
#  'on',
#  'of',
#  'excitedly',
#  'enraged',
#  'of',
#  'at',
#  'all',
#  'older',
#  'and',
#  'an',
#  'emerald',
#  'of',
#  'it',
#  'obviously',
#  'it',
#  'on',
#  'and',
#  'arrived',
#  'in',
#  'on',
#  'always',
#  'in',
#  'office',
#  'on',
#  'If',
#  'it',
#  'on',
#  'owls',
#  'in',
#  'in',
#  'and',
#  'open',
#  'as',
#  'owl',
#  'after',
#  'owl',
#  'overhead',
#  'of',
#  'an',
#  'owl',
#  'even',
#  'at',
#  'owl',
#  'at',
#  'important',
#  'and',
#  'in',
#  'until',
#  'and',
#  'across',
#  'all',
#  'about',
#  'in',
#  'until',
#  'of',
#  'eyed',
#  'angrily',
#  'as',
#  'uneasy',
#  'excitedly',
#  'and',
#  'It',
#  'on',
#  'in',
#  'of',
#  'at',
#  'as',
#  'if',
#  'of',
#  'it',
#  'across',
#  'up',
#  'office',
#  'at',
#  'and',
#  'almost',
#  'and',
#  'an',
#  'unusual',
#  'of',
#  'of',
#  'it',
#  'even',
#  'even',
#  'It',
#  'Or',
#  'in',
#  'always',
#  'upset',
#  'at',
#  'any',
#  'of',
#  'if',
#  'all',
#  'in',
#  'it',
#  'on',
#  'afternoon',
#  'and',
#  'at',
#  'into',
#  'outside',
#  'as',
#  'old',
#  'and',
#  'almost',
#  'It',
#  'at',
#  'all',
#  'upset',
#  'at',
#  'almost',
#  'On',
#  'into',
#  'and',
#  'in',
#  'upset',
#  'at',
#  'Even',
#  'And',
#  'old',
#  'around',
#  'and',
#  'off',
#  'also',
#  'and',
#  'off',
#  'imagining',
#  'approve',
#  'of',
#  'imagination',
#  'As',
#  'into',
#  'of',
#  'and',
#  'it',
#  'improve',
#  'It',
#  'on',
#  'it',
#  'one',
#  'it',
#  'around',
#  'its',
#  'eyes',
#  'It',
#  'into',
#  'anything',
#  'over',
#  'all',
#  'about',
#  'and',
#  'act',
#  'into',
#  'in',
#  'on',
#  'evening',
#  'And',
#  'everywhere',
#  'owls',
#  'unusually',
#  'Although',
#  'owls',
#  'at',
#  'and',
#  'are',
#  'ever',
#  'in',
#  'of',
#  'of',
#  'in',
#  'every',
#  'Experts',
#  'are',
#  'unable',
#  'explain',
#  'owls',
#  'allowed',
#  'And',
#  'over',
#  'any',
#  'of',
#  'owls',
#  'about',
#  'it',
#  'only',
#  'owls',
#  'acting',
#  'oddly',
#  'as',
#  'apart',
#  'as',
#  'and',
#  'in',
#  'instead',
#  'of',
#  'of',
#  'early',
#  'it',
#  'until',
#  'in',
#  'armchair',
#  'all',
#  'over',
#  'Owls',
#  'in',
#  'all',
#  'over',
#  'And',
#  'about',
#  'into',
#  'of',
#  'It',
#  'Er',
#  'As',
#  'expected',
#  'and',
#  'angry',
#  'After',
#  'all',
#  'on',
#  'Owls',
#  'and',
#  'of',
#  'in',
#  'it',
#  'Instead',
#  'as',
#  'as',
#  'about',
#  'age',
#  'again',
#  'isn',
#  'it',
#  'if',
#  'ask',
#  'Oh',
#  'agree',
#  'another',
#  'on',
#  'as',
#  'upstairs',
#  'in',
#  'and',
#  'into',
#  'It',
#  'as',
#  'it',
#  'imagining',
#  'all',
#  'anything',
#  'If',
#  'it',
#  'if',
#  'it',
#  'out',
#  'of',
#  'it',
#  'into',
#  'asleep',
#  'awake',
#  'it',
#  'all',
#  'over',
#  'in',
#  'asleep',
#  'even',
#  'if',
#  'involved',
#  'and',
#  'and',
#  'about',
#  'and',
#  'and',
#  'up',
#  'in',
#  'anything',
#  'on',
#  'and',
#  'over',
#  'it',
#  'affect',
#  'into',
#  'an',
#  'uneasy',
#  'on',
#  'outside',
#  'of',
#  'It',
#  'as',
#  'as',
#  'its',
#  'eyes',
#  'unblinkingly',
#  'on',
#  'of',
#  'It',
#  'as',
#  'on',
#  'owls',
#  'overhead',
#  'In',
#  'it',
#  'at',
#  'all',
#  'appeared',
#  'on',
#  'appeared',
#  'and',
#  'out',
#  'of',
#  'and',
#  'its',
#  'eyes',
#  'ever',
#  'on',
#  'and',
#  'old',
#  'of',
#  'and',
#  'enough',
#  'into',
#  'and',
#  'eyes',
#  'and',
#  'and',
#  'and',
#  'as',
#  'it',
#  'at',
#  'Albus',
#  'Albus',
#  'arrived',
#  'in',
#  'everything',
#  'unwelcome',
#  'in',
#  'up',
#  'at',
#  'at',
#  'other',
#  'end',
#  'of',
#  'of',
#  'amuse',
#  'and',
#  'in',
#  'inside',
#  'It',
#  'it',
#  'open',
#  'it',
#  'up',
#  'in',
#  'air',
#  'and',
#  'it',
#  'out',
#  'it',
#  'again',
#  'into',
#  'Outer',
#  'until',
#  'only',
#  'on',
#  'in',
#  'eyes',
#  'of',
#  'If',
#  'anyone',
#  'out',
#  'of',
#  'even',
#  'eyed',
#  'able',
#  'anything',
#  'on',
#  'Outer',
#  'inside',
#  'and',
#  'off',
#  'on',
#  'at',
#  'it',
#  'after',
#  'it',
#  'at',
#  'it',
#  'Instead',
#  'at',
#  'exactly',
#  'of',
#  'around',
#  'its',
#  'eyes',
#  'an',
#  'emerald',
#  'one',
#  'into',
#  'it',
#  'asked',
#  'if',
#  'on',
#  'all',
#  'All',
#  'and',
#  'on',
#  'angrily',
#  'Oh',
#  'everyone',
#  'all',
#  'impatiently',
#  'even',
#  'on',
#  'It',
#  'on',
#  'at',
#  'it',
#  'of',
#  'owls',
#  'in',
#  'eleven',
#  'irritably',
#  'our',
#  'are',
#  'out',
#  'on',
#  'in',
#  'even',
#  'in',
#  'at',
#  'as',
#  'on',
#  'it',
#  'if',
#  'on',
#  'at',
#  'out',
#  'about',
#  'us',
#  'all',
#  'It',
#  'of',
#  'of',
#  'as',
#  'As',
#  'even',
#  'if',
#  'All',
#  'eleven',
#  'unsticking',
#  'It',
#  'all',
#  'if',
#  'any',
#  'of',
#  'exasperated',
#  'admiring',
#  'Everyone',
#  'only',
#  'one',
#  'oh',
#  'all',
#  'of',
#  'Only',
#  'use',
#  'It',
#  'it',
#  'earmuffs',
#  'at',
#  'and',
#  'owls',
#  'are',
#  'are',
#  'around',
#  'everyone',
#  'About',
#  'About',
#  'It',
#  'anxious',
#  'on',
#  'all',
#  'as',
#  'as',
#  'as',
#  'It',
#  'everyone',
#  'it',
#  'until',
#  'it',
#  'another',
#  'and',
#  'answer',
#  'on',
#  'is',
#  'up',
#  'in',
#  'is',
#  'and',
#  'are',
#  'are',
#  'and',
#  'it',
#  'it',
#  'Oh',
#  'Albus',
#  'out',
#  'and',
#  'on',
#  'as',
#  'on',
#  'all',
#  'one',
#  'or',
#  'and',
#  'It',
#  'it',
#  'After',
#  'all',
#  'all',
#  'It',
#  'astounding',
#  'of',
#  'all',
#  'in',
#  'of',
#  'only',
#  'out',
#  'and',
#  'at',
#  'eyes',
#  'as',
#  'and',
#  'examined',
#  'it',
#  'It',
#  'odd',
#  'It',
#  'instead',
#  'around',
#  'edge',
#  'It',
#  'it',
#  'in',
#  'and',
#  'it',
#  'And',
#  'of',
#  'all',
#  'aunt',
#  'and',
#  'uncle',
#  'only',
#  'and',
#  'at',
#  'all',
#  'are',
#  'us',
#  'And',
#  'all',
#  'up',
#  'and',
#  'It',
#  'aunt',
#  'and',
#  'uncle',
#  'able',
#  'explain',
#  'everything',
#  'older',
#  'on',
#  'explain',
#  'all',
#  'in',
#  'understand',
#  'if',
#  'as',
#  'in',
#  'about',
#  'every',
#  'in',
#  'our',
#  'Exactly',
#  'over',
#  'of',
#  'It',
#  'enough',
#  'any',
#  'and',
#  'even',
#  'off',
#  'up',
#  'away',
#  'all',
#  'until',
#  'it',
#  'opened',
#  'and',
#  'of',
#  'is',
#  'eyed',
#  'as',
#  'underneath',
#  'it',
#  'it',
#  'as',
#  'important',
#  'as',
#  'isn',
#  'in',
#  'around',
#  'It',
#  'as',
#  'up',
#  'and',
#  'of',
#  'it',
#  'as',
#  'up',
#  'at',
#  'and',
#  'out',
#  'of',
#  'air',
#  'and',
#  'on',
#  'in',
#  'of',
#  'If',
#  'it',
#  'astride',
#  'it',
#  'almost',
#  'as',
#  'as',
#  'and',
#  'at',
#  'as',
#  'allowed',
#  'and',
#  'of',
#  'and',
#  'of',
#  'of',
#  'and',
#  'in',
#  'In',
#  'arms',
#  'of',
#  'At',
#  'And',
#  'it',
#  'off',
#  'as',
#  'it',
#  'almost',
#  'out',
#  'all',
#  'around',
#  'asleep',
#  'as',
#  'over',
#  'and',
#  'over',
#  'of',
#  'Inside',
#  'asleep',
#  'Under',
#  'of',
#  'over',
#  'of',
#  'Is',
#  'about',
#  'it',
#  'Even',
#  'if',
#  'in',
#  'one',
#  'above',
#  'is',
#  'of',
#  'Underground',
#  'over',
#  'in',
#  'arms',
#  'and',
#  'asked',
#  'over',
#  'and',
#  'out',
#  'out',
#  'and',
#  'in',
#  'it',
#  'it',
#  'an',
#  'an',
#  'off',
#  'it',
#  'all',
#  'on',
#  'or',
#  'on',
#  'arm',
#  'as',
#  'over',
#  'and',
#  'on',
#  'out',
#  'of',
#  'it',
#  'inside',
#  'and',
#  'other',
#  'of',
#  'and',
#  'at',
#  'and',
#  'usually',
#  'eyes',
#  'out',
#  'as',
#  'and',
#  'in',
#  'away',
#  'eyes',
#  'on',
#  'onto',
#  'and',
#  'engine',
#  'into',
#  'it',
#  'into',
#  'air',
#  'and',
#  'off',
#  'into',
#  'expect',
#  'in',
#  'and',
#  'On',
#  'and',
#  'out',
#  'Outer',
#  'it',
#  'once',
#  'and',
#  'of',
#  'orange',
#  'and',
#  'out',
#  'around',
#  'at',
#  'other',
#  'end',
#  'of',
#  'of',
#  'on',
#  'of',
#  'on',
#  'and',
#  'of',
#  'of',
#  'and',
#  'under',
#  'inky',
#  'expect',
#  'astonishing',
#  'over',
#  'inside',
#  'up',
#  'One',
#  'on',
#  'and',
#  'on',
#  'in',
#  'as',
#  'opened',
#  'out',
#  'and',
#  'at',
#  'in',
#  'all',
#  'over',
#  'up',
#  'and',
#  'in',
#  'up',
#  'on',
#  'at',
#  'all',
#  'on',
#  'and',
#  'up',
#  'on',
#  'it',
#  'into',
#  'almost',
#  'exactly',
#  'as',
#  'it',
#  'on',
#  'about',
#  'owls',
#  'Only',
#  'on',
#  'ago',
#  'of',
#  'of',
#  'and',
#  'on',
#  'at',
#  'and',
#  'at',
#  'all',
#  'another',
#  'in',
#  'asleep',
#  'at',
#  'Aunt',
#  'awake',
#  'and',
#  'it',
#  'of',
#  'Up',
#  'up',
#  'aunt',
#  'on',
#  'again',
#  'Up',
#  'and',
#  'of',
#  'on',
#  'onto',
#  'and',
#  'It',
#  'one',
#  'in',
#  'it',
#  'aunt',
#  'outside',
#  'Are',
#  'up',
#  'on',
#  'after',
#  'And',
#  'it',
#  'everything',
#  'on',
#  'aunt',
#  'out',
#  'of',
#  'and',
#  'under',
#  'and',
#  'after',
#  'off',
#  'one',
#  'of',
#  'on',
#  'used',
#  'under',
#  'of',
#  'and',
#  'into',
#  'almost',
#  'all',
#  'It',
#  'as',
#  'and',
#  'Exactly',
#  'as',
#  'and',
#  'exercise',
#  'unless',
#  'of',
#  'it',
#  ...]

# %%
# find every word that ends in "ing"

re.findall("\w+ing\\b", story)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/jy/00b3p4p15ql2hkl3cmb83swm0000gn/T/ipykernel_4244/4284453136.py:3: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("\w+ing\\b", story)
# ['anything',
#  'craning',
#  'spying',
#  'everything',
#  'nothing',
#  'keeping',
#  'mixing',
#  'nothing',
#  'happening',
#  'boring',
#  'screaming',
#  'having',
#  'throwing',
#  'something',
#  'reading',
#  'standing',
#  'thinking',
#  'reading',
#  'looking',
#  'nothing',
#  'hoping',
#  'something',
#  'morning',
#  'noticing',
#  'steering',
#  'standing',
#  'whispering',
#  'wearing',
#  'collecting',
#  'something',
#  'parking',
#  'morning',
#  'swooping',
#  'morning',
#  'whispering',
#  'collecting',
#  'clutching',
#  'saying',
#  'something',
#  'dialing',
#  'thinking',
#  'being',
#  'worrying',
#  'building',
#  'wearing',
#  'being',
#  'nothing',
#  'celebrating',
#  'hoping',
#  'imagining',
#  'thing',
#  'morning',
#  'sitting',
#  'Trying',
#  'anything',
#  'living',
#  'evening',
#  'behaving',
#  'flying',
#  'sleeping',
#  'Going',
#  'acting',
#  'phoning',
#  'shooting',
#  'celebrating',
#  'Shooting',
#  'flying',
#  'living',
#  'carrying',
#  'something',
#  'shooting',
#  'looking',
#  'something',
#  'sinking',
#  'staring',
#  'waiting',
#  'something',
#  'imagining',
#  'anything',
#  'turning',
#  'comforting',
#  'anything',
#  'going',
#  'drifting',
#  'showing',
#  'sitting',
#  'watching',
#  'Nothing',
#  'judging',
#  'wearing',
#  'sparkling',
#  'everything',
#  'rummaging',
#  'looking',
#  'something',
#  'being',
#  'staring',
#  'looking',
#  'watching',
#  'anything',
#  'happening',
#  'seeing',
#  'smiling',
#  'looking',
#  'wearing',
#  'wearing',
#  'sitting',
#  'celebrating',
#  'celebrating',
#  'something',
#  'going',
#  'living',
#  'shooting',
#  'something',
#  'Shooting',
#  'being',
#  'swapping',
#  'hoping',
#  'going',
#  'something',
#  'thing',
#  'trying',
#  'unsticking',
#  'confusing',
#  'saying',
#  'saying',
#  'sounding',
#  'admiring',
#  'nothing',
#  'flying',
#  'saying',
#  'waiting',
#  'piercing',
#  'saying',
#  'going',
#  'choosing',
#  'saying',
#  'saying',
#  'saying',
#  'astounding',
#  'moving',
#  'going',
#  'bring',
#  'jumping',
#  'pointing',
#  'watching',
#  'kicking',
#  'screaming',
#  'everything',
#  'sitting',
#  'looking',
#  'something',
#  'growing',
#  'getting',
#  'hiding',
#  'bringing',
#  'something',
#  'saying',
#  'rumbling',
#  'nothing',
#  'sitting',
#  'holding',
#  'sounding',
#  'climbing',
#  'lightning',
#  'something',
#  'taking',
#  'burying',
#  'patting',
#  'twinkling',
#  'staying',
#  'Wiping',
#  'streaming',
#  'nodding',
#  'slinking',
#  'astonishing',
#  'waking',
#  'knowing',
#  'knowing',
#  'knowing',
#  'being',
#  'meeting',
#  'holding',
#  'saying',
#  'living',
#  'wearing',
#  'riding',
#  'playing',
#  'being',
#  'walking',
#  'frying',
#  'being',
#  'having',
#  'flying',
#  'feeling',
#  'everything',
#  'Nothing',
#  'nothing',
#  'looking',
#  'pulling',
#  'racing',
#  'racing',
#  'punching',
#  'punching',
#  'something',
#  'living',
#  'thing',
#  'lightning',
#  'asking',
#  'turning',
#  'morning',
#  'greeting',
#  'frying',
#  'counting',
#  'looking',
#  'Darling',
#  'going',
#  'coming',
#  'wolfing',
#  'racing',
#  'ripping',
#  'looking',
#  'looking',
#  'something',
#  'listening',
#  'sitting',
#  'crying',
#  'anything',
#  'flinging',
#  'everything',
#  'pretending',
#  'sitting',
#  'anything',
#  'warning',
#  'putting',
#  'warning',
#  'anything',
#  'going',
#  'anything',
#  'telling',
#  'coming',
#  'looking',
#  'imagining',
#  'morning',
#  'trying',
#  'revolting',
#  'being',
#  'chasing',
#  'sitting',
#  'telling',
#  'climbing',
#  'nothing',
#  'going',
#  'being',
#  'spending',
#  'smelling',
#  'living',
#  'morning',
#  'roaring',
#  'remembering',
#  'flying',
#  'anything',
#  'thing',
#  'asking',
#  'talking',
#  'anything',
#  'acting',
#  'smiling',
#  'licking',
#  'scratching',
#  'morning',
#  'starting',
#  'hitting',
#  'crawling',
#  'slithering',
#  'crushing',
#  'staring',
#  'glistening',
#  'boring',
#  'drumming',
#  'trying',
#  'having',
#  'hammering',
#  'watching',
#  'ceiling',
#  'annoying',
#  'deafening',
#  'waddling',
#  'punching',
#  'leaning',
#  'uncoiling',
#  'slithering',
#  'running',
#  'hissing',
#  'saying',
#  'anything',
#  'telling',
#  'swearing',
#  'calming',
#  'talking',
#  'starting',
#  'wishing',
#  'sneaking',
#  'being',
#  'during',
#  'blinding',
#  'burning',
#  'coming',
#  'shopping',
#  'asking',
#  'buying',
#  'anything',
#  'looking',
#  'thing',
#  'racing',
#  'escaping',
#  'Hunting',
#  'wandering',
#  'thinking',
#  'going',
#  'going',
#  'going',
#  'anything',
#  'leaving',
#  'tripping',
#  'evening',
#  'living',
#  'hitting',
#  'looking',
#  'training',
#  'trying',
#  'morning',
#  'coming',
#  'swimming',
#  'dyeing',
#  'going',
#  'wearing',
#  'Smelting',
#  'Smelting',
#  'Smelting',
#  'vacationing',
#  'twanging',
#  'asking',
#  'Whinging',
#  'Turning',
#  'trembling',
#  'bearing',
#  'surrounding',
#  'doing',
#  'checking',
#  'staring',
#  'something',
#  'unfolding',
#  'trying',
#  'writing',
#  'shaking',
#  'glancing',
#  'choking',
#  'seeming',
#  'being',
#  'Smelting',
#  'stuffing',
#  'slamming',
#  'dangling',
#  'saying',
#  'quivering',
#  'watching',
#  'Watching',
#  'spying',
#  'following',
#  'pacing',
#  'anything',
#  'having',
#  'evening',
#  'something',
#  'writing',
#  'ceiling',
#  'thinking',
#  'getting',
#  'everything',
#  'everything',
#  'lying',
#  'working',
#  'bawling',
#  'anything',
#  'morning',
#  'Smelting',
#  'thinking',
#  'wishing',
#  'looking',
#  'trying',
#  'banging',
#  'Smelting',
#  'fighting',
#  'Smelting',
#  'gasping',
#  'morning',
#  'turning',
#  'going',
#  'something',
#  'something',
#  'something',
#  'lying',
#  'sleeping',
#  'making',
#  'trying',
#  'tearing',
#  'trying',
#  'burning',
#  'living',
#  'trying',
#  'morning',
#  'looking',
#  'Something',
#  'whizzing',
#  'pelting',
#  'trying',
#  'streaming',
#  'bouncing',
#  'trying',
#  'pulling',
#  'going',
#  'missing',
#  'speeding',
#  'sniffling',
#  'holding',
#  'going',
#  'howling',
#  'blowing',
#  'looking',
#  'sitting',
#  'staring',
#  'passing',
#  'wondering',
#  'standing',
#  'following',
#  'dining',
#  'looking',
#  'thing',
#  'parking',
#  'something',
#  'smiling',
#  'carrying',
#  'pointing',
#  'thing',
#  'clapping',
#  'ambling',
#  'pointing',
#  'bobbing',
#  'freezing',
#  'slipping',
#  'sliding',
#  'reaching',
#  'trying',
#  'rumbling',
#  'dangling',
#  'wondering',
#  'wondering',
#  'something',
#  'going',
#  'slapping',
#  'crunching',
#  'crumbling',
#  'staring',
#  'knocking',
#  'skidding',
#  'holding',
#  'deafening',
#  'standing',
#  'glinting',
#  'stooping',
#  'ceiling',
#  'crouching',
#  'rasping',
#  'breaking',
#  'entering',
#  'being',
#  'turning',
#  'trembling',
#  'icing',
#  'rubbing',
#  'doing',
#  'roaring',
#  'flickering',
#  'taking',
#  'starting',
#  'sizzling',
#  'thing',
#  'working',
#  'anything',
#  'anything',
#  'anything',
#  'turning',
#  'cowering',
#  'going',
#  'something',
#  'fixing',
#  'anything',
#  'whistling',
#  'sitting',
#  'clapping',
#  'looking',
#  'Taking',
#  'talking',
#  'looking',
#  'going',
#  'being',
#  'turning',
#  'having',
#  'ranting',
#  'wanting',
#  'jumping',
#  'living',
#  'thing',
#  'Something',
#  'going',
#  'blinding',
#  'something',
#  'watching',
#  'glaring',
#  'something',
#  'nothing',
#  'beating',
#  'denying',
#  'getting',
#  'wizarding',
#  'Pointing',
#  'warning',
#  'warning',
#  'being',
#  'breathing',
#  'sitting',
#  'blazing',
#  'feeling',
#  'being',
#  'thing',
#  'dreading',
#  'going',
#  'realizing',
#  'doing',
#  'smiling',
#  'beaming',
#  'going',
#  'going',
#  'going',
#  'swishing',
#  'dancing',
#  'howling',
#  'poking',
#  'Pulling',
#  'everything',
#  'morning',
#  'going',
#  'tapping',
#  'knocking',
#  'sinking',
#  'getting',
#  'rapping',
#  'swelling',
#  'savaging',
#  'nothing',
#  'string',
#  'looking',
#  'turning',
#  'looking',
#  'something',
#  'pulling',
#  'standing',
#  'scratching',
#  'anything',
#  'holding',
#  'anything',
#  'looking',
#  'staring',
#  'trying',
#  'flying',
#  'giving',
#  'unfolding',
#  'turning',
#  'morning',
#  'pointing',
#  'parking',
#  'saying',
#  'panting',
#  'knitting',
#  'everything',
#  'following',
#  'Waffling',
#  'bring',
#  'going',
#  'getting',
#  'bustling',
#  'everything',
#  'trusting',
#  'coming',
#  'looking',
#  'hurrying',
#  'feeling',
#  'sitting',
#  'drinking',
#  'smoking',
#  'talking',
#  'saying',
#  'clapping',
#  'making',
#  'peering',
#  'looking',
#  'puffing',
#  'realizing',
#  'beaming',
#  'scraping',
#  'shaking',
#  'meeting',
#  'looking',
#  'coming',
#  'twitching',
#  'grasping',
#  'getting',
#  'nothing',
#  'swimming',
#  'counting',
#  'facing',
#  'Stirring',
#  'hanging',
#  'trying',
#  'everything',
#  'doing',
#  'shopping',
#  'shaking',
#  'saying',
#  'hooting',
#  'saying',
#  'selling',
#  'selling',
#  'tottering',
#  'building',
#  'Standing',
#  'wearing',
#  'facing',
#  'finding',
#  'sitting',
#  'scribbling',
#  'weighing',
#  'examining',
#  'leading',
#  'showing',
#  'Morning',
#  'emptying',
#  'scattering',
#  'weighing',
#  'glowing',
#  'holding',
#  'throwing',
#  'handing',
#  'leading',
#  'flaming',
#  'hurtling',
#  'twisting',
#  'rattling',
#  'steering',
#  'passing',
#  'ceiling',
#  'trembling',
#  'billowing',
#  'blinking',
#  'belonging',
#  'going',
#  'gathering',
#  'rattling',
#  'Something',
#  'expecting',
#  'lying',
#  'blinking',
#  'holding',
#  'nodding',
#  'feeling',
#  'smiling',
#  'being',
#  'standing',
#  'buying',
#  'looking',
#  'drawling',
#  'going',
#  'racing',
#  'getting',
#  'wondering',
#  'feeling',
#  'being',
#  'wishing',
#  'something',
#  'interesting',
#  'nodding',
#  'standing',
#  'grinning',
#  'pointing',
#  'something',
#  'liking',
#  'setting',
#  'going',
#  'sounding',
#  'wizarding',
#  'talking',
#  'drawling',
#  'Nothing',
#  'ceiling',
#  'paving',
#  'nothing',
#  'anything',
#  'Tying',
#  'trying',
#  'weighing',
#  'fascinating',
#  'ceiling',
#  'rustling',
#  'flickering',
#  'wing',
#  'stammering',
#  'sounding',
#  'looking',
#  'Peeling',
#  'tinkling',
#  'ceiling',
#  'crunching',
#  'standing',
#  'shining',
#  'seeing',
#  'buying',
#  'lightning',
#  'going',
#  'shuffling',
#  'giving',
#  'piercing',
#  'measuring',
#  'doing',
#  'flitting',
#  'taking',
#  'heartstring',
#  'feeling',
#  'waiting',
#  'mounting',
#  'swishing',
#  'throwing',
#  'dancing',
#  'muttering',
#  'gawking',
#  'looking',
#  'Everything',
#  'trying',
#  'anything',
#  'beginning',
#  'King',
#  'anything',
#  'depressing',
#  'interesting',
#  'reading',
#  'swooping',
#  'bringing',
#  'counting',
#  'getting',
#  'King',
#  'living',
#  'watching',
#  'listening',
#  'King',
#  'anything',
#  'realizing',
#  'Barking',
#  'howling',
#  'King',
#  'going',
#  'going',
#  'trying',
#  'Taking',
#  'morning',
#  'everything',
#  'waiting',
#  'sitting',
#  'King',
#  'facing',
#  'nothing',
#  'laughing',
#  'going',
#  'starting',
#  'passing',
#  'being',
#  'Getting',
#  'muttering',
#  'trying',
#  'According',
#  'something',
#  'tapping',
#  'tapping',
#  'saying',
#  'talking',
#  'flaming',
#  'pushing',
#  'hammering',
#  'saying',
#  'holding',
#  'dividing',
#  'swarming',
#  'joking',
#  'walking',
#  'nothing',
#  'gangling',
#  'thing',
#  'thing',
#  'going',
#  'leaning',
#  'coming',
#  'running',
#  'waiting',
#  'chattering',
#  'scraping',
#  'hanging',
#  'fighting',
#  'saying',
#  'something',
#  'pushing',
#  'pointing',
#  'lightning',
#  'turning',
#  'floating',
#  'Coming',
#  'saying',
#  'something',
#  'rubbing',
#  'coming',
#  'striding',
#  'billowing',
#  'something',
#  'saying',
#  'something',
#  'telling',
#  'looking',
#  'something',
#  'lightning',
#  'reminding',
#  'joking',
#  'waving',
#  'laughing',
#  'crying',
#  'running',
#  'going',
#  'leaving',
#  'sitting',
#  'pointing',
#  'pretending',
#  'going',
#  'lightning',
#  'Nothing',
#  'nothing',
#  'doing',
#  'interesting',
#  'wizarding',
#  'looking',
#  'anything',
#  'being',
#  'staring',
#  'anything',
#  'being',
#  'having',
#  'getting',
#  'anything',
#  'being',
#  'sounding',
#  'trying',
#  'anything',
#  'saying',
#  'voicing',
#  'something',
#  'worrying',
#  'talking',
#  'speeding',
#  'watching',
#  'clattering',
#  'smiling',
#  'Anything',
#  'rattling',
#  'Blowing',
#  'wanting',
#  'anything',
#  'everything',
#  'Starving',
#  'taking',
#  'holding',
#  'anything',
#  'feeling',
#  'sitting',
#  'eating',
#  'holding',
#  'starting',
#  'nothing',
#  'missing',
#  'flowing',
#  'bowling',
#  'collecting',
#  'waiting',
#  'eating',
#  'looking',
#  'scratching',
#  'eating',
#  'flying',
#  'becoming',
#  'twisting',
#  'getting',
#  'snoozing',
#  'interesting',
#  'looking',
#  'something',
#  'glinting',
#  'poking',
#  'wearing',
#  'listening',
#  'looking',
#  'doing',
#  'nothing',
#  'reading',
#  'Wizarding',
#  'feeling',
#  'everything',
#  'asking',
#  'taking',
#  'settling',
#  'looking',
#  'trying',
#  'wondering',
#  'studying',
#  'doing',
#  'something',
#  'Nothing',
#  'anything',
#  'something',
#  'starting',
#  'entering',
#  'saying',
#  'worrying',
#  'explaining',
#  'describing',
#  'taking',
#  'looking',
#  'saying',
#  'looking',
#  'Standing',
#  'noticing',
#  'looking',
#  'hiding',
#  'wizarding',
#  'making',
#  'going',
#  'leaving',
#  'hanging',
#  'howling',
#  'lurking',
#  'going',
#  'looking',
#  'picking',
#  'meeting',
#  'something',
#  'fighting',
#  'fighting',
#  'scowling',
#  'leaving',
#  'behaving',
#  'racing',
#  'getting',
#  'slowing',
#  'reaching',
#  'thronging',
#  'bobbing',
#  'Slipping',
#  'stumbling',
#  'losing',
#  'sparkling',
#  'pointing',
#  'sitting',
#  'gliding',
#  'staring',
#  'opening',
#  'taking',
#  'checking',
#  'holding',
#  'coming',
#  'flaming',
#  'ceiling',
#  'facing',
#  'standing',
#  'peering',
#  'Sorting',
#  'something',
#  'outstanding',
#  'breaking',
#  'Sorting',
#  'waiting',
#  'joking',
#  'something',
#  'talking',
#  'whispering',
#  'wondering',
#  'saying',
#  ...]
